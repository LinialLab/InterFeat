# %% [markdown]
# * Get a list of my known/selected/extracted features, for comparison with known literature for a disease.
#
# * e.g. `Cholelithiasis` -  https://www.ncbi.nlm.nih.gov/books/NBK470440/
#     * https://chatgpt.com/share/8764ca22-828f-457b-8cc4-22319a68e8b1
#
#
#
#  TODO: Add NMR feats etc'

# %%
import pandas as pd

# %%
features_list = pd.read_csv("ukb_gallstone_feature_report.csv")["name"]
features_list
# Out:
# 0                                            age_X_sex
# 1                   HDL cholesterol Blood biochemistry
# 2                                       Abdominal pain
# 3                     Triglycerides Blood biochemistry
# 4                                          Triglycerid
#                             ...
# 304                                  Cerebral ischemia
# 305                    Other upper respiratory disease
# 306    Nonspecific abnormal findings in stool contents
# 307                                         Acute pain
# 308                               Cancer of oropharynx
# Name: name, Length: 309, dtype: object

# %%
df2 = pd.read_csv("ukbb-hack/Data/data_aux.csv.gz").drop(columns=["Participant ID"])
df2.columns = df2.columns.str.replace(" | Instance 0","",regex=False).str.replace(" | Instance 0","",regex=False).str.replace("| Array 0","",regex=False)
print(df2.columns)
df2
# Out:
# Index(['Standard PRS for age at menopause (AAM)',
#        'Standard PRS for age-related macular degeneration (AMD)',
#        'Standard PRS for alzheimer's disease (AD)',
#        'Standard PRS for asthma (AST)',
#        'Standard PRS for atrial fibrillation (AF)',
#        'Standard PRS for bipolar disorder (BD)',
#        'Standard PRS for body mass index (BMI)',
#        'Standard PRS for bowel cancer (CRC)',
#        'Standard PRS for breast cancer (BC)',
#        'Standard PRS for cardiovascular disease (CVD)',
#        'Standard PRS for coeliac disease (CED)',
#        'Standard PRS for coronary artery disease (CAD)',
#        'Standard PRS for crohn's disease (CD)',
#        'Standard PRS for epithelial ovarian cancer (EOC)',
#        'Standard PRS for estimated bone mineral density t-score (EBMDT)',
#        'Standard PRS for glycated haemoglobin (HBA1C_DF)',
#        'Standard PRS for height (HEIGHT)',
#        'Standard PRS for high density lipoprotein cholesterol (HDL)',
#        'Standard PRS for hypertension (HT)',
#        'Standard PRS for intraocular pressure (IOP)',
#        'Standard PRS for ischaemic stroke (ISS)',
#        'Standard PRS for low density lipoprotein cholesterol (LDL_SF)',
#        'Standard PRS for melanoma (MEL)',
#        'Standard PRS for multiple sclerosis (MS)',
#        'Standard PRS for osteoporosis (OP)',
#        'Standard PRS for parkinson's disease (PD)',
#        'Standard PRS for primary open angle glaucoma (POAG)',
#        'Standard PRS for prostate cancer (PC)',
#        'Standard PRS for psoriasis (PSO)',
#        'Standard PRS for rheumatoid arthritis (RA)',
#        'Standard PRS for schizophrenia (SCZ)',
#        'Standard PRS for systemic lupus erythematosus (SLE)',
#        'Standard PRS for type 1 diabetes (T1D)',
#        'Standard PRS for type 2 diabetes (T2D)',
#        'Standard PRS for ulcerative colitis (UC)',
#        'Standard PRS for venous thromboembolic disease (VTE)',
#        'PRS genetic principal components ',
#        'Townsend deprivation index at recruitment', 'Birth weight',
#        'Cascot confidence score'],
#       dtype='object')
#         Standard PRS for age at menopause (AAM)  \
# 0                                      1.594120
# 1                                     -2.042420
# 2                                      0.047436
# 3                                     -0.877326
# 4                                     -0.765377
# ...                                         ...
# 502165                                -0.287166
# 502166                                 0.342977
# 502167                                -0.030788
# 502168                                -0.790808
# 502169                                 0.822251
#
#         Standard PRS for age-related macular degeneration (AMD)  \
# 0                                               -0.472454
# 1                                                0.823560
# 2                                                0.378806
# 3                                                1.132440
# 4                                                0.729507
# ...                                                   ...
# 502165                                           2.429460
# 502166                                           0.322170
# 502167                                           1.298290
# 502168                                          -0.279981
# 502169                                          -0.133669
#
#         Standard PRS for alzheimer's disease (AD)  \
# 0                                        0.318543
# 1                                       -1.271560
# 2                                        0.883113
# 3                                       -0.493331
# 4                                        0.352771
# ...                                           ...
# 502165                                  -0.579973
# 502166                                   0.167737
# 502167                                  -0.874670
# 502168                                   0.637864
# 502169                                   0.399994
#
#         Standard PRS for asthma (AST)  \
# 0                           -0.608597
# 1                           -1.745390
# 2                           -0.413509
# 3                           -0.255172
# 4                            0.024505
# ...                               ...
# 502165                       1.234190
# 502166                       0.864450
# 502167                       0.113862
# 502168                       0.280993
# 502169                      -1.174720
#
#         Standard PRS for atrial fibrillation (AF)  \
# 0                                        0.732505
# 1                                       -1.313440
# 2                                       -0.067494
# 3                                        0.638398
# 4                                        0.558936
# ...                                           ...
# 502165                                  -0.255566
# 502166                                   1.035130
# 502167                                   1.433390
# 502168                                   0.763564
# 502169                                   0.425856
#
#         Standard PRS for bipolar disorder (BD)  \
# 0                                    -1.236850
# 1                                    -0.586529
# 2                                    -0.699923
# 3                                    -0.124744
# 4                                    -0.329746
# ...                                        ...
# 502165                                0.840383
# 502166                                0.156692
# 502167                                1.439560
# 502168                               -1.328590
# 502169                               -0.412371
#
#         Standard PRS for body mass index (BMI)  \
# 0                                    -1.017890
# 1                                     1.892600
# 2                                     1.727930
# 3                                     0.448447
# 4                                     0.993897
# ...                                        ...
# 502165                                0.196219
# 502166                                0.336019
# 502167                               -0.852973
# 502168                                1.867700
# 502169                               -1.181680
#
#         Standard PRS for bowel cancer (CRC)  \
# 0                                  0.441509
# 1                                  1.446960
# 2                                 -0.728904
# 3                                  1.559180
# 4                                 -1.218300
# ...                                     ...
# 502165                             2.917120
# 502166                             2.478980
# 502167                            -0.409313
# 502168                             0.272875
# 502169                             0.885879
#
#         Standard PRS for breast cancer (BC)  \
# 0                                 -0.632416
# 1                                 -0.248250
# 2                                 -1.332350
# 3                                 -0.217675
# 4                                 -0.303386
# ...                                     ...
# 502165                             0.363257
# 502166                            -1.137110
# 502167                            -0.258747
# 502168                            -0.875791
# 502169                            -0.164586
#
#         Standard PRS for cardiovascular disease (CVD)  ...  \
# 0                                            1.234230  ...
# 1                                           -1.081420  ...
# 2                                            0.458169  ...
# 3                                           -0.584126  ...
# 4                                            0.906272  ...
# ...                                               ...  ...
# 502165                                      -0.014443  ...
# 502166                                       0.466944  ...
# 502167                                       0.284876  ...
# 502168                                      -0.975812  ...
# 502169                                      -1.108360  ...
#
#         Standard PRS for schizophrenia (SCZ)  \
# 0                                  -0.043712
# 1                                  -1.664590
# 2                                  -0.397792
# 3                                   1.016900
# 4                                  -0.483350
# ...                                      ...
# 502165                              1.164330
# 502166                             -0.137776
# 502167                              0.997540
# 502168                             -0.211614
# 502169                             -2.228420
#
#         Standard PRS for systemic lupus erythematosus (SLE)  \
# 0                                               -0.004664
# 1                                               -0.751579
# 2                                                0.519007
# 3                                               -0.019071
# 4                                               -0.294396
# ...                                                   ...
# 502165                                           0.458337
# 502166                                          -0.415820
# 502167                                           0.613056
# 502168                                           0.518454
# 502169                                          -1.142030
#
#         Standard PRS for type 1 diabetes (T1D)  \
# 0                                     2.507540
# 1                                    -0.401147
# 2                                     1.504330
# 3                                     0.300340
# 4                                     1.004550
# ...                                        ...
# 502165                               -0.785070
# 502166                               -1.232220
# 502167                                1.457850
# 502168                                0.336882
# 502169                               -0.699462
#
#         Standard PRS for type 2 diabetes (T2D)  \
# 0                                    -0.878088
# 1                                    -0.445942
# 2                                     1.762930
# 3                                    -0.660356
# 4                                    -0.229111
# ...                                        ...
# 502165                                0.388690
# 502166                                1.604560
# 502167                                0.885614
# 502168                                0.005927
# 502169                               -0.285601
#
#         Standard PRS for ulcerative colitis (UC)  \
# 0                                       1.101050
# 1                                       0.202860
# 2                                       0.080039
# 3                                      -1.143810
# 4                                      -0.211714
# ...                                          ...
# 502165                                  1.713490
# 502166                                  0.325049
# 502167                                 -0.423670
# 502168                                  1.846990
# 502169                                 -0.445535
#
#         Standard PRS for venous thromboembolic disease (VTE)  \
# 0                                                2.334520
# 1                                               -1.475670
# 2                                                0.121405
# 3                                                0.873744
# 4                                                0.067843
# ...                                                   ...
# 502165                                           0.859654
# 502166                                           0.710914
# 502167                                          -1.790220
# 502168                                           1.685530
# 502169                                          -1.824240
#
#         PRS genetic principal components   \
# 0                                -8.86839
# 1                                -9.00802
# 2                                -9.99725
# 3                                -8.48041
# 4                                -8.50595
# ...                                   ...
# 502165                           -8.74261
# 502166                           -8.87252
# 502167                           -9.82085
# 502168                           -7.83523
# 502169                           -9.09736
#
#         Townsend deprivation index at recruitment  Birth weight  \
# 0                                           -4.22          3.20
# 1                                           -3.67          3.63
# 2                                           -5.88          2.78
# 3                                            0.25          3.06
# 4                                           -4.94          3.18
# ...                                           ...           ...
# 502165                                       1.94           NaN
# 502166                                       0.77           NaN
# 502167                                      -3.42          2.72
# 502168                                      -5.23          3.26
# 502169                                      -3.75          3.40
#
#         Cascot confidence score
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 502165                      NaN
# 502166                      NaN
# 502167                      NaN
# 502168                      NaN
# 502169                      NaN
#
# [502170 rows x 40 columns]

# %%
df3 = pd.read_csv("ukbb-hack/Data/data_aux_2.csv.gz").drop(columns=["Participant ID"])
df3.columns = df3.columns.str.replace(" | Instance 0","",regex=False).str.replace(" | Instance 0","",regex=False).str.replace("| Array 0","",regex=False).str.replace(" | Instance 1","",regex=False)
print(df3.columns)
df3
# Out:
# Index(['Overall health rating',
#        'Long-standing illness, disability or infirmity',
#        'Falls in the last year', 'Weight change compared with 1 year ago',
#        'General pain for 3+ months', 'Fluid intelligence score',
#        'Medication for cholesterol, blood pressure, diabetes, or take exogenous hormones',
#        'Eye problems/disorders',
#        'Non-accidental death in close genetic family',
#        'Medication for cholesterol, blood pressure or diabetes',
#        'Basophill count', 'Basophill percentage', 'Eosinophill percentage',
#        'Haematocrit percentage', 'Haemoglobin concentration',
#        'Mean platelet (thrombocyte) volume', 'Coffee intake', 'Tea intake',
#        'Country of Birth (non-UK origin)', 'Ethnic background',
#        'Genetic ethnic grouping', 'Total protein', 'Triglycerides', 'SHBG',
#        'Phosphate'],
#       dtype='object')
#        Overall health rating Long-standing illness, disability or infirmity  \
# 0                       Good                                            Yes
# 1                       Good                                            Yes
# 2                       Good                                            Yes
# 3                       Good                                            Yes
# 4                       Good                                             No
# ...                      ...                                            ...
# 502160                  Good                                            Yes
# 502161                  Poor                                            Yes
# 502162             Excellent                                             No
# 502163             Excellent                                             No
# 502164                  Good                                             No
#
#        Falls in the last year Weight change compared with 1 year ago  \
# 0                    No falls              No - weigh about the same
# 1                    No falls                      Yes - lost weight
# 2                    No falls              No - weigh about the same
# 3               Only one fall                    Yes - gained weight
# 4                    No falls              No - weigh about the same
# ...                       ...                                    ...
# 502160     More than one fall                    Yes - gained weight
# 502161     More than one fall              No - weigh about the same
# 502162               No falls              No - weigh about the same
# 502163               No falls              No - weigh about the same
# 502164               No falls              No - weigh about the same
#
#        General pain for 3+ months  Fluid intelligence score  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                             NaN                      10.0
# 4                             NaN                       NaN
# ...                           ...                       ...
# 502160                        NaN                       NaN
# 502161                        NaN                       NaN
# 502162                        NaN                       NaN
# 502163                        NaN                       NaN
# 502164                        NaN                      10.0
#
#        Medication for cholesterol, blood pressure, diabetes, or take exogenous hormones  \
# 0                                       None of the above
# 1                                                     NaN
# 2                                                     NaN
# 3                                       None of the above
# 4                             Hormone replacement therapy
# ...                                                   ...
# 502160                                  None of the above
# 502161                                  None of the above
# 502162                                  None of the above
# 502163                                                NaN
# 502164                                                NaN
#
#        Eye problems/disorders Non-accidental death in close genetic family  \
# 0                         NaN                                          NaN
# 1                         NaN                                          NaN
# 2                         NaN                                          NaN
# 3           None of the above                                           No
# 4                         NaN                                          NaN
# ...                       ...                                          ...
# 502160                    NaN                                          NaN
# 502161                    NaN                                          Yes
# 502162      None of the above                                          NaN
# 502163                    NaN                                          NaN
# 502164                    NaN                                           No
#
#        Medication for cholesterol, blood pressure or diabetes  ...  \
# 0                                                     NaN      ...
# 1                                                     NaN      ...
# 2                         Cholesterol lowering medication      ...
# 3                                                     NaN      ...
# 4                                                     NaN      ...
# ...                                                   ...      ...
# 502160                                                NaN      ...
# 502161                                                NaN      ...
# 502162                                                NaN      ...
# 502163                          Blood pressure medication      ...
# 502164                                  None of the above      ...
#
#         Mean platelet (thrombocyte) volume  Coffee intake  Tea intake  \
# 0                                     9.88              6           0
# 1                                      NaN              1           6
# 2                                    13.00  Less than one           6
# 3                                     7.49              0           4
# 4                                    10.22              2           8
# ...                                    ...            ...         ...
# 502160                                9.20              1           4
# 502161                                 NaN              0           3
# 502162                                8.81              0           1
# 502163                               10.20              1           6
# 502164                                9.40              5           2
#
#         Country of Birth (non-UK origin)  Ethnic background  \
# 0                                    NaN            British
# 1                                    NaN            British
# 2                                    NaN            British
# 3                                    NaN            British
# 4                                    NaN            British
# ...                                  ...                ...
# 502160                               NaN            British
# 502161                             Congo            African
# 502162                               NaN            British
# 502163                               NaN            British
# 502164                               NaN            British
#
#         Genetic ethnic grouping Total protein Triglycerides    SHBG Phosphate
# 0                     Caucasian         66.40         1.478   57.21       NaN
# 1                           NaN           NaN           NaN     NaN       NaN
# 2                     Caucasian         70.43         0.450   42.12       NaN
# 3                     Caucasian         70.90         1.581   87.63       NaN
# 4                     Caucasian         76.80         1.056   43.59       NaN
# ...                         ...           ...           ...     ...       ...
# 502160                      NaN         72.13         1.648   31.18       NaN
# 502161                      NaN           NaN           NaN     NaN       NaN
# 502162                      NaN         66.32         1.927  108.49       NaN
# 502163                Caucasian         68.40         1.877   36.54       NaN
# 502164                Caucasian         67.19         1.881   31.62       NaN
#
# [502165 rows x 25 columns]

# %%
features_list = features_list.to_list()
features_list.extend(df2.columns.tolist())
features_list.extend(df3.columns.tolist())
features_list = list(set(features_list))
print(len(features_list))
# Out:
# 340

# %%
features_list
# Out:
# ['Ileostomy status',
#  'Triglycerides',
#  'Other mental disorder',
#  'Cascot confidence score',
#  'Standard PRS for breast cancer (BC)',
#  'Uterine/Uterovaginal prolapse',
#  'Urinary tract infection',
#  'General pain for 3+ months',
#  'Mitral valve disease',
#  'Country of Birth (non-UK origin)',
#  'Tea intake',
#  'Standard PRS for systemic lupus erythematosus (SLE)',
#  'Poisoning by analgesics, antipyretics, and antirheumatics',
#  'Redundant prepuce and phimosis/BXO',
#  'Cerebral artery occlusion, with cerebral infarction',
#  'Dizziness and giddiness (Light-headedness and vertigo)',
#  'Iron deficiency anemias, unspecified or not due to blood loss',
#  'Benign neoplasm of other parts of digestive system',
#  'Abdominal aortic aneurysm',
#  'Congestive heart failure (CHF) NOS',
#  'Bronchiectasis',
#  'Other disorders of male genital organs',
#  'Acute appendicitis',
#  'Palpitations',
#  'Other intestinal obstruction',
#  'Dysuria',
#  'Cellulitis and abscess of foot, toe',
#  'Symptoms concerning nutrition, metabolism, and development',
#  'Hyposmolality and/or hyponatremia',
#  'Esophagitis, GERD and related diseases',
#  'Flatulence',
#  'Fever of unknown origin',
#  'Esophageal bleeding (varices/hemorrhage)',
#  'Vitamin B-complex deficiencies',
#  'Standard PRS for intraocular pressure (IOP)',
#  'Arterial embolism and thrombosis of lower extremity artery',
#  'Cyst and pseudocyst of pancreas',
#  'Standard PRS for low density lipoprotein cholesterol (LDL_SF)',
#  'Disorders of magnesium metabolism',
#  'Secondary malignancy of bone',
#  'Excessive or frequent menstruation',
#  'Phosphate',
#  'Abnormal function study of cardiovascular system',
#  'Osteoarthrosis, localized, primary',
#  'Diseases of the larynx and vocal cords',
#  'Other upper respiratory disease',
#  'Cataract',
#  'Haematocrit percentag',
#  'Occlusion of cerebral arteries',
#  'Hypovolemia',
#  'Ulcer of esophagus',
#  'Abnormality of gait',
#  'Eosinophill percentage',
#  'age_X_sex',
#  'Coffee intake',
#  'Standard PRS for coeliac disease (CED)',
#  'Average Diameter for HDL Particl',
#  'Hypotension NOS',
#  'Duodenal ulcer',
#  'Melanomas of skin',
#  'Sleep apnea',
#  'Late effects of cerebrovascular disease',
#  'Cholelithiasis with other cholecystitis',
#  'Portal hypertension',
#  'Calculus of kidney',
#  'Atopic/contact dermatitis due to other or unspecified',
#  'Hemorrhage from gastrointestinal ulcer',
#  'Standard PRS for epithelial ovarian cancer (EOC)',
#  'Cardiomegaly',
#  'Standard PRS for coronary artery disease (CAD)',
#  'Alcoholism',
#  'Standard PRS for type 2 diabetes (T2D)',
#  'PRS genetic principal components | Array',
#  'Malignant neoplasm, other',
#  'Non-accidental death in close genetic family',
#  'Postoperative infection',
#  'age',
#  'Osteoporosis NOS',
#  'Postinflammatory pulmonary fibrosis',
#  'Malaise and fatigue',
#  'Hydronephrosis',
#  'Gout',
#  'Benign neoplasm of colon',
#  'Regional enteritis',
#  'Type 2 diabetes',
#  'Cerebral degeneration, unspecified',
#  'Concentration of Small HDL Particl',
#  'Abdominal pain',
#  'Senile cataract',
#  'Unspecified monoarthritis',
#  'Other disorders of bladder',
#  'Alcohol-related disorders',
#  'Pain in joint',
#  'Standard PRS for osteoporosis (OP)',
#  'Heartburn',
#  'Symptoms involving digestive system',
#  'Other forms of chronic heart disease',
#  'Other benign neoplasm of connective and other soft tissue',
#  'Birth weigh',
#  'Abnormal findings on exam of gastrointestinal tract/ abdominal area',
#  'Other chronic nonalcoholic liver disease',
#  'Acquired toe deformities',
#  'Reflux esophagitis',
#  'Bacterial enteritis',
#  'Dental caries',
#  'Basophill cou',
#  'Standard PRS for estimated bone mineral density t-score (EBMDT)',
#  'Standard PRS for hypertension (HT)',
#  'Secondary malignant neoplasm of liver',
#  'Standard PRS for rheumatoid arthritis (RA)',
#  'Heart valve replaced',
#  'Abnormal results of function study of liver',
#  'Concentration of VLDL Particl',
#  'Pneumonia',
#  'Standard PRS for multiple sclerosis (MS)',
#  'Other ill-defined and unknown causes of morbidity and mortality',
#  'Blood in stool',
#  'Medication for cholesterol, blood pressure, diabetes, or take exogenous hormones',
#  'E. coli',
#  'Cholesterol in Medium HDL',
#  'Angina pectoris',
#  "Standard PRS for crohn's disease (CD)",
#  'Falls in the last year',
#  'Cholesterol in Large LDL',
#  'Hypotension',
#  'Diaphragmatic hernia',
#  'Abnormal findings examination of lungs',
#  'Cholesterol in Very Large HDL',
#  'Opiates and related narcotics causing adverse effects in therapeutic use',
#  'Cholesterol in Large VLDL',
#  'Cholesterol in Small HDL',
#  'Genetic ethnic grouping',
#  'Obstructive chronic bronchitis',
#  'Hyperlipidemia',
#  'Concentration of Very Large HDL Particl',
#  'Acute pain',
#  'Obesity',
#  'Malignant neoplasm of female breast',
#  'LDL direct Blood biochemistry',
#  'Total protein',
#  'Streptococcus infection',
#  'Hematemesis',
#  'Respiratory failure',
#  'Peripheral enthesopathies and allied syndromes',
#  'Standard PRS for cardiovascular disease (CVD)',
#  'Polymyalgia Rheumatica',
#  'Cystic kidney disease',
#  'Other specified gastritis',
#  'Acute renal failure',
#  'Concentration of Medium HDL Particl',
#  'Apolipoprotein A Blood biochemistry',
#  'Townsend deprivation index at recruitm',
#  'Cholesterol Blood biochemistry',
#  'Eye problems/disorders',
#  'Standard PRS for glycated haemoglobin (HBA1C_DF)',
#  'Uterine leiomyoma',
#  'Shortness of breath',
#  'Other symptoms/disorders or the urinary system',
#  'Cancer of bladder',
#  'Standard PRS for age at menopause (AAM)',
#  'Weight change compared with 1 year ago',
#  'Duodenitis',
#  'Anal and rectal conditions',
#  'Other anemias',
#  'Personal history of diseases of digestive system',
#  'Ethnic background',
#  'Retention of urine',
#  'Complication of internal orthopedic device',
#  'Chronic airway obstruction',
#  'GERD',
#  'Standard PRS for psoriasis (PSO)',
#  'Fluid intelligence score',
#  'Average Diameter for VLDL Particl',
#  'Standard PRS for venous thromboembolic disease (VTE)',
#  'Triglycerides Blood biochemistry',
#  'PRS genetic principal components ',
#  'Agorophobia, social phobia, and panic disorder',
#  'Concentration of HDL Particl',
#  'Epistaxis or throat hemorrhage',
#  'Superficial injury without mention of infection',
#  'HDL cholesterol Blood biochemistry',
#  'Hemangioma and lymphangioma, any site',
#  'Gastric ulcer',
#  "Contracture of palmar fascia [Dupuytren's disease]",
#  'Dysphagia',
#  'Cholesterol in IDL',
#  'Symptoms involving head and neck',
#  'Seborrheic keratosis',
#  'Total protei',
#  'Diverticulosis',
#  'Type 1 diabetes',
#  'Standard PRS for bipolar disorder (BD)',
#  'Urethral stricture (not specified as infectious)',
#  'Prolapse of vaginal walls',
#  'Left bundle branch block',
#  'Hemorrhoids',
#  'Aphakia and other disorders of lens',
#  'Blindness and low vision',
#  'Haematocrit percentage',
#  'Standard PRS for atrial fibrillation (AF)',
#  'Other diseases of respiratory system, NEC',
#  'Ulcerative colitis',
#  'Nonspecific chest pain',
#  'Complication of colostomy or enterostomy',
#  'Injury, NOS',
#  'Abnormal granulation tissue',
#  'Other disorders of liver',
#  'Haemoglobin concentration',
#  'Standard PRS for asthma (AST)',
#  'Neutropenia',
#  'Disturbance of skin sensation',
#  'Poisoning by antibiotics',
#  'Anal and rectal polyp',
#  'Concentration of Very Large VLDL Particl',
#  'Stricture and stenosis of esophagus',
#  'Malignant neoplasm of other and ill-defined sites within the digestive organs and peritoneum',
#  'Septal Deviations/Turbinate Hypertrophy',
#  'Sepsis',
#  'Concentration of Medium LDL Particl',
#  'Standard PRS for height (HEIGHT)',
#  'Townsend deprivation index at recruitment',
#  'Atrial fibrillation and flutter',
#  'Occlusion and stenosis of precerebral arteries',
#  'Concentration of Large VLDL Particl',
#  'Malignant neoplasm of rectum, rectosigmoid junction, and anus',
#  'Other disorders of eyelids',
#  'Effects radiation NOS',
#  'Cholelithiasis',
#  'Emphysema',
#  'Cystitis',
#  'Breast cancer [female]',
#  'Concentration of Very Small VLDL Particl',
#  'Other disorders of stomach and duodenum',
#  'Medication for cholesterol, blood pressure or diabetes',
#  'Standard PRS for melanoma (MEL)',
#  'Triglycerid',
#  'Birth weight',
#  'Standard PRS for schizophrenia (SCZ)',
#  'Hypopotassemia',
#  'Haemoglobin concentratio',
#  'Pain in limb',
#  'Neurological disorders',
#  "Standard PRS for parkinson's disease (PD)",
#  'Chronic prostatitis',
#  'Septicemia',
#  'Circulatory disease NEC',
#  'Standard PRS for bowel cancer (CRC)',
#  'Back pain',
#  'Anxiety disorder',
#  'Coronary atherosclerosis',
#  "Standard PRS for alzheimer's disease (AD)",
#  'Phosphate | Instance 1',
#  'Edema',
#  'Standard PRS for ulcerative colitis (UC)',
#  'Unstable angina (intermediate coronary syndrome)',
#  'Acquired spondylolisthesis',
#  'Other tests',
#  'Cancer of urinary organs (incl. kidney and bladder)',
#  'Other disorders of intestine',
#  'Chronic ulcer of skin',
#  'stress incontinence, female',
#  'SHBG',
#  'Inguinal hernia',
#  'Abnormal findings on examination of urine',
#  'Allergy/adverse effect of penicillin',
#  'Apolipoprotein B Blood biochemistry',
#  'Secondary malignancy of respiratory organs',
#  'Glaucoma',
#  'Bacterial infection NOS',
#  'Abnormal heart sounds',
#  'Transient cerebral ischemia',
#  'Basophill percentage',
#  'Other abnormal blood chemistry',
#  'Varicose veins of lower extremity',
#  'Standard PRS for high density lipoprotein cholesterol (HDL)',
#  'Standard PRS for primary open angle glaucoma (POAG)',
#  'Nonspecific abnormal findings in stool contents',
#  'Phlebitis and thrombophlebitis of lower extremities',
#  'Hypercholesterolemia',
#  'Other non-epithelial cancer of skin',
#  'Acute pancreatitis',
#  'Fluid intelligence scor',
#  'Cerebrovascular disease',
#  'Other chronic ischemic heart disease, unspecified',
#  'Standard PRS for type 1 diabetes (T1D)',
#  'Arrhythmia (cardiac) NOS',
#  'Staphylococcus infections',
#  'Standard PRS for age-related macular degeneration (AMD)',
#  'Cancer of bronchus; lung',
#  'Overall health rating',
#  'Pleurisy; pleural effusion',
#  'Cholesterol in Very Large VLDL',
#  'Basophill percentag',
#  'Basophill count',
#  'Syncope and collapse',
#  'Chronic renal failure [CKD]',
#  'Umbilical hernia',
#  'Cerebral ischemia',
#  'Standard PRS for ischaemic stroke (ISS)',
#  'Nausea and vomiting',
#  'Cyst of kidney, acquired',
#  'Cancer of prostate',
#  'Cholesterol in Small VLDL',
#  'Peripheral vascular disease, unspecified',
#  'Convulsions',
#  'Arthropathy NOS',
#  'Diseases of hair and hair follicles',
#  'Cholecystitis without cholelithiasis',
#  'Noninfectious gastroenteritis',
#  'Hematuria',
#  'Long-standing illness, disability or infirmity',
#  'Heart failure NOS',
#  'Concentration of Large HDL Particl',
#  'Constipation',
#  'Open wounds of extremities',
#  'Rash and other nonspecific skin eruption',
#  'Pneumococcal pneumonia',
#  'Iatrogenic hypotension',
#  'Hypertensive chronic kidney disease',
#  'Ganglion and cyst of synovium, tendon, and bursa',
#  'Concentration of Chylomicrons and Extremely Large VLDL Particl',
#  'Gastritis and duodenitis',
#  'Calculus of lower urinary tract',
#  'Standard PRS for prostate cancer (PC)',
#  'Acquired absence of breast',
#  'Hemorrhage of gastrointestinal tract',
#  'Complication due to other implant and internal device',
#  'Cancer of oropharynx',
#  'Precordial pain',
#  'Other acute and subacute forms of ischemic heart disease',
#  'Abdominal hernia',
#  'Complications of cardiac/vascular device, implant, and graft',
#  'Pernicious anemia',
#  'Other open wound of head and face',
#  'Standard PRS for body mass index (BMI)',
#  'Myocardial infarction',
#  'Vitamin D deficiency',
#  'Mean platelet (thrombocyte) volume',
#  'Respiratory insufficiency',
#  'Cervicalgia']
