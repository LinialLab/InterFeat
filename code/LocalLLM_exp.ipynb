# %% [markdown]
# ### Experiment with a local llm as judge, critic etc'
# * Need to use code from elsewhere for munging candidates into prompts
# * Open Medical-LLM Leaderboard: https://huggingface.co/spaces/openlifescienceai/open_medical_llm_leaderboard
# * Need to try diff models
# * https://www.reddit.com/r/LocalLLaMA/comments/1cec23f/llama3_based_openbiollm70b_8b_outperforms_gpt4/
# *  https://huggingface.co/aaditya/Llama3-OpenBioLLM-8B

# %%
# ## https://colab.research.google.com/drive/1F5oV20InEYeAJGmBwYF9NM_QhLmjBkKJ?usp=sharing#scrollTo=fca6d8cfwOUO
# # !CMAKE_ARGS="-DLLAMA_CUBLAS=on" pip install llama-cpp-python
# !pip install llama-cpp-python

# %%
# !pip install torch torchvision transformers -U
# !pip3 install torch torchvision torchaudio transformers sentence-transformers -U
# !conda uninstall tokenizers -y
# !pip3 install tokenizers transformers -U
# !pip3 install safetensors
# !pip3 install accelerate datasets peft trl bitsnbytes -U

# %%
import transformers
import torch
import pandas as pd
from tqdm import tqdm
import re
from sentence_transformers import SentenceTransformer
import numpy as np

ANNOT_DATA = "../.././Reports/example_plausible_gallstones.csv"

# %%
# # https://colab.research.google.com/drive/1F5oV20InEYeAJGmBwYF9NM_QhLmjBkKJ?usp=sharing#scrollTo=2xawFMf70x7F
# from huggingface_hub import hf_hub_download
# from llama_cpp import Llama
# 
# model_name = "aaditya/OpenBioLLM-Llama3-8B-GGUF"
# model_file = "openbiollm-llama3-8b.Q5_K_M.gguf"
# 
# model_path = hf_hub_download(model_name,
#                              filename=model_file,
#                              # local_dir='/content
#                              )
# print("My model path: ", model_path)
# llm = Llama(model_path=model_path,
#             n_gpu_layers=-1)

# %%
# Question = "How can i split a 3mg or 4mg waefin pill so i can get a 2.5mg pill?"
# 
# #ORIG:
# # prompt = f"You are an expert and experienced from the healthcare and biomedical domain with extensive medical knowledge and practical experience. Your name is OpenBioLLM, and you were developed by Saama AI Labs with Open Life Science AI. who's willing to help answer the user's query with explanation. In your explanation, leverage your deep medical expertise such as relevant anatomical structures, physiological processes, diagnostic criteria, treatment guidelines, or other pertinent medical concepts. Use precise medical terminology while still aiming to make the explanation clear and accessible to a general audience. Medical Question: {Question} Medical Answer:"
# #ALT:
# prompt = f"""You are an expert and experienced researcher from the healthcare and biomedical domain with extensive medical knowledge and practical experience. Willing to help answer the user's query with explanation. 
# In your explanation, leverage your deep medical expertise such as relevant anatomical structures, physiological processes, diagnostic criteria, treatment guidelines, or other pertinent medical concepts and scientific literature.
# Use precise terminology while still aiming to make the explanation clear and accessible. Medical Question: {Question} Medical Answer:"""
# 
# response = llm(prompt, max_tokens=64)['choices'][0]['text']
# 
# print("\n\n\n", response)

# %%
# model_id = "aaditya/OpenBioLLM-Llama3-8B"

# pipeline = transformers.pipeline(
#     "text-generation",
#     model=model_id,
#     model_kwargs={"torch_dtype": torch.bfloat16},
#     device="mps"
#     # "auto",
# )

# ## I changed prompt
# messages = [
#     {"role": "system", "content": "You are an expert and experienced researcher from the healthcare and biomedical domain with extensive medical knowledge and practical experience. Willing to help answer the user's query with explanation. In your explanation, leverage your deep medical expertise such as relevant anatomical structures, physiological processes, diagnostic criteria, treatment guidelines, or other pertinent medical concepts and scientific literature. Use precise terminology while still aiming to make the explanation clear and accessible."},
#     {"role": "user", "content": "How can i split a 3mg or 4mg waefin pill so i can get a 2.5mg pill?"},
# ]

# prompt = pipeline.tokenizer.apply_chat_template(
#         messages, 
#         tokenize=False, 
#         add_generation_prompt=True
# )

# terminators = [
#     pipeline.tokenizer.eos_token_id,
#     pipeline.tokenizer.convert_tokens_to_ids("<|eot_id|>")
# ]

# outputs = pipeline(
#     prompt,
#     max_new_tokens= 64#256,
#     ,eos_token_id=terminators,
#     do_sample=True,
#     temperature=0.0
#     ,top_p=0.9,
# )
# print(outputs[0]["generated_text"][len(prompt):])

# %% [markdown]
# ### Load existing annotated examples and get inference on them
# * 0-shot.
# * Could use embeddings?

# %%
df = pd.read_csv(ANNOT_DATA)
## Could filter by p-values or uncommented cases
DROP_UNCOMMENTED_EXAMPLES = False

data = df.drop_duplicates(subset=df.select_dtypes(["O","bool"]).columns)
print(data.shape[0])
if DROP_UNCOMMENTED_EXAMPLES:
    data = data.loc[~data["COMMENTS"].isna()].copy()
    print(data.shape[0])
# #Drop more cases - context limit, or for test set
# data = data.loc[~data['COMMENTS'].str.contains("P val|p-val|correlation|ordinal|similar to",case=False,na=False)]
# print(data.shape[0])
# # data = data.drop_duplicates(subset=['feature_name']).drop_duplicates(subset=['COMMENTS']) ## 31 -> 27
# data = data.drop_duplicates(subset=['feature_name','COMMENTS']) ## 
print(data.shape)
display(data)
# Out:
# 84
# (84, 10)
#                                          feature_name  feature_importance  \
# 0   Long-standing illness, disability or infirmity...               0.041
# 1                            Alanine aminotransferase               0.032
# 2                Mouth/teeth dental problems Dentures               0.023
# 3                          Overall health rating Fair               0.016
# 4           Standard PRS for alzheimer's disease (AD)               0.012
# ..                                                ...                 ...
# 79                                  3-Hydroxybutyrate               0.001
# 80                             Hallux valgus (Bunion)               0.001
# 81  Cholesterol in Chylomicrons and Extremely Larg...               0.001
# 82                           Job code at visit clerks               0.001
# 83          Other diseases of respiratory system, NEC               0.001
#
#     p_val  correlation  MutualInfoTarget  Co-occurrence Count  \
# 0   0.000        0.049               NaN                    0
# 1   0.000        0.027               NaN                    0
# 2   0.000        0.031               NaN                    0
# 3   0.000        0.043               NaN                    0
# 4   0.000       -0.008               NaN                    0
# ..    ...          ...               ...                  ...
# 79  0.306       -0.002               0.0                    0
# 80  0.095        0.000               0.0                    0
# 81  0.000        0.002               0.0                    0
# 82  0.080       -0.003               0.0                    0
# 83  0.303       -0.002               0.0                    0
#
#                                                Target  Interesting?  \
# 0   (Cholelithiasis) OR (Gallstones) OR (Gallbladd...          True
# 1   (Cholelithiasis) OR (Gallstones) OR (Gallbladd...         False
# 2   (Cholelithiasis) OR (Gallstones) OR (Gallbladd...          True
# 3   (Cholelithiasis) OR (Gallstones) OR (Gallbladd...         False
# 4   (Cholelithiasis) OR (Gallstones) OR (Gallbladd...          True
# ..                                                ...           ...
# 79  (Cholelithiasis) OR (Gallstones) OR (Gallbladd...         False
# 80  (Cholelithiasis) OR (Gallstones) OR (Gallbladd...         False
# 81  (Cholelithiasis) OR (Gallstones) OR (Gallbladd...          True
# 82  (Cholelithiasis) OR (Gallstones) OR (Gallbladd...         False
# 83  (Cholelithiasis) OR (Gallstones) OR (Gallbladd...         False
#
#     Plausible/Makes Sense?                                           COMMENTS
# 0                     True                                   CVD risk factors
# 1                     True                                      liver enzyme
# 2                     True                                          nutrition
# 3                    False                                                NaN
# 4                     True                                                NaN
# ..                     ...                                                ...
# 79                   False                     High P value + low correlation
# 80                   False                     High P value + low correlation
# 81                   False   - Our meta-analysis found insufficient eviden...
# 82                   False  This is a not an ordinal data (i assume)  - pr...
# 83                   False                     High P value + low correlation
#
# [84 rows x 10 columns]

# %% [markdown]
# ## Load updated candidates (containing more metadata) and see if can match it to the annotations

# %%
# df_update = pd.read_csv("gallstone_review_interesting_candidates_results.csv")
# gallstone_ipw_broad_feature_report.csv
df_update = pd.read_csv("../../broad_candidate_novel_cuis_chol.csv")
print(df_update.shape[0]) ## multiple rows per feature 
numeric_cols = df_update.select_dtypes(include='number').columns
# df_update = df_update.drop_duplicates(["feature_name"])
df_update = df_update.groupby(["feature_name"])[numeric_cols].max()#min()
print(df_update.shape[0])
df_update
# Out:
# 950
# 365
#                                                     KG_Hits  sim_score  \
# feature_name
# 3-Hydroxybutyrate                                         0      0.767
# A09.9 - Gastroenteritis and colitis of unspecif...        0      1.000
# Abnormal results of function study of liver               0      1.000
# Acetate                                                   0      0.788
# Acetoacetate                                              0      0.987
# ...                                                     ...        ...
# problem                                                   0      0.726
# prolapsed                                                 0      1.000
# reflux gord                                               0      1.000
# spondylitis                                               0      0.904
# tissue                                                    0      0.692
#
#                                                     feature_level_min_kg_hits  \
# feature_name
# 3-Hydroxybutyrate                                                         0.0
# A09.9 - Gastroenteritis and colitis of unspecif...                        0.0
# Abnormal results of function study of liver                               0.0
# Acetate                                                                   0.0
# Acetoacetate                                                              0.0
# ...                                                                       ...
# problem                                                                   0.0
# prolapsed                                                                 0.0
# reflux gord                                                               0.0
# spondylitis                                                               0.0
# tissue                                                                    0.0
#
#                                                     feature_level_sum_kg_hits  \
# feature_name
# 3-Hydroxybutyrate                                                         0.0
# A09.9 - Gastroenteritis and colitis of unspecif...                        0.0
# Abnormal results of function study of liver                               1.0
# Acetate                                                                   0.0
# Acetoacetate                                                              0.0
# ...                                                                       ...
# problem                                                                   0.0
# prolapsed                                                                 0.0
# reflux gord                                                               0.0
# spondylitis                                                               0.0
# tissue                                                                    0.0
#
#                                                     feature_level_avg_kg_hits  \
# feature_name
# 3-Hydroxybutyrate                                                         0.0
# A09.9 - Gastroenteritis and colitis of unspecif...                        0.0
# Abnormal results of function study of liver                               0.3
# Acetate                                                                   0.0
# Acetoacetate                                                              0.0
# ...                                                                       ...
# problem                                                                   0.0
# prolapsed                                                                 0.0
# reflux gord                                                               0.0
# spondylitis                                                               0.0
# tissue                                                                    0.0
#
#                                                     feature_importance  \
# feature_name
# 3-Hydroxybutyrate                                               0.0036
# A09.9 - Gastroenteritis and colitis of unspecif...              0.0013
# Abnormal results of function study of liver                     0.0019
# Acetate                                                         0.0036
# Acetoacetate                                                    0.0054
# ...                                                                ...
# problem                                                         0.0005
# prolapsed                                                       0.0002
# reflux gord                                                     0.0003
# spondylitis                                                     0.0023
# tissue                                                          0.0002
#
#                                                      p_val   corr  \
# feature_name
# 3-Hydroxybutyrate                                   0.0911 -0.002
# A09.9 - Gastroenteritis and colitis of unspecif...  0.0000  0.010
# Abnormal results of function study of liver         0.0000  0.015
# Acetate                                             0.3443 -0.010
# Acetoacetate                                        0.6066 -0.001
# ...                                                    ...    ...
# problem                                             0.0000  0.010
# prolapsed                                           0.0438  0.005
# reflux gord                                         0.0000  0.015
# spondylitis                                         0.0000  0.011
# tissue                                              0.0780 -0.004
#
#                                                     MutualInfoTarget  \
# feature_name
# 3-Hydroxybutyrate                                             0.0000
# A09.9 - Gastroenteritis and colitis of unspecif...            0.0000
# Abnormal results of function study of liver                   0.0008
# Acetate                                                       0.0003
# Acetoacetate                                                  0.0000
# ...                                                              ...
# problem                                                       0.0012
# prolapsed                                                     0.0000
# reflux gord                                                   0.0000
# spondylitis                                                   0.0005
# tissue                                                        0.0003
#
#                                                     F.Split-Lift (y==1)  \
# feature_name
# 3-Hydroxybutyrate                                                  1.01
# A09.9 - Gastroenteritis and colitis of unspecif...                 2.05
# Abnormal results of function study of liver                        2.87
# Acetate                                                            1.77
# Acetoacetate                                                       1.67
# ...                                                                 ...
# problem                                                            1.67
# prolapsed                                                          1.20
# reflux gord                                                        1.42
# spondylitis                                                        1.85
# tissue                                                             1.00
#
#                                                     F.Split-Support  \
# feature_name
# 3-Hydroxybutyrate                                            185870
# A09.9 - Gastroenteritis and colitis of unspecif...              400
# Abnormal results of function study of liver                     143
# Acetate                                                         164
# Acetoacetate                                                    251
# ...                                                             ...
# problem                                                         263
# prolapsed                                                       890
# reflux gord                                                    2259
# spondylitis                                                     195
# tissue                                                       195745
#
#                                                     sim_score_target_feat  \
# feature_name
# 3-Hydroxybutyrate                                                    0.00
# A09.9 - Gastroenteritis and colitis of unspecif...                   0.16
# Abnormal results of function study of liver                          0.21
# Acetate                                                             -0.04
# Acetoacetate                                                        -0.00
# ...                                                                   ...
# problem                                                              0.12
# prolapsed                                                            0.19
# reflux gord                                                          0.28
# spondylitis                                                          0.24
# tissue                                                               0.17
#
#                                                     sim_score_target_cui  \
# feature_name
# 3-Hydroxybutyrate                                                   0.00
# A09.9 - Gastroenteritis and colitis of unspecif...                  0.16
# Abnormal results of function study of liver                         0.21
# Acetate                                                            -0.04
# Acetoacetate                                                       -0.00
# ...                                                                  ...
# problem                                                             0.21
# prolapsed                                                           0.19
# reflux gord                                                         0.28
# spondylitis                                                         0.27
# tissue                                                              0.19
#
#                                                     shortest_path_length  \
# feature_name
# 3-Hydroxybutyrate                                                      2
# A09.9 - Gastroenteritis and colitis of unspecif...                     2
# Abnormal results of function study of liver                           99
# Acetate                                                                2
# Acetoacetate                                                           2
# ...                                                                  ...
# problem                                                                2
# prolapsed                                                              2
# reflux gord                                                            2
# spondylitis                                                            2
# tissue                                                                 2
#
#                                                     simple_path_length  \
# feature_name
# 3-Hydroxybutyrate                                                   20
# A09.9 - Gastroenteritis and colitis of unspecif...                  41
# Abnormal results of function study of liver                         18
# Acetate                                                             62
# Acetoacetate                                                         6
# ...                                                                ...
# problem                                                             38
# prolapsed                                                           18
# reflux gord                                                         18
# spondylitis                                                         26
# tissue                                                             170
#
#                                                     norm_path_length
# feature_name
# 3-Hydroxybutyrate                                               0.07
# A09.9 - Gastroenteritis and colitis of unspecif...              0.20
# Abnormal results of function study of liver                     0.11
# Acetate                                                         0.04
# Acetoacetate                                                    0.07
# ...                                                              ...
# problem                                                         0.07
# prolapsed                                                       0.11
# reflux gord                                                     0.11
# spondylitis                                                     0.15
# tissue                                                          0.01
#
# [365 rows x 16 columns]

# %%
# print(df_update.merge(data,on="feature_name",how="right", suffixes=('', '_DROP')).filter(regex='^(?!.*_DROP)').shape)
s1 = data.shape[0]
data = data.merge(df_update,on="feature_name",how="left", suffixes=('', '_DROP')).filter(regex='^(?!.*_DROP)')
assert s1 == data.shape[0]

# %%
print("Corr")
data.select_dtypes(["number","bool"]).corr().round(2)[["Interesting?","Plausible/Makes Sense?"]].dropna(axis=0).sort_values("Interesting?")
# Out:
# Corr
#                            Interesting?  Plausible/Makes Sense?
# shortest_path_length              -0.29                   -0.38
# p_val                             -0.26                   -0.38
# corr                              -0.22                   -0.18
# MutualInfoTarget                  -0.10                    0.01
# simple_path_length                -0.07                    0.17
# F.Split-Support                   -0.04                    0.11
# feature_importance                 0.01                    0.29
# sim_score_target_cui               0.01                   -0.16
# sim_score_target_feat              0.08                   -0.14
# sim_score                          0.09                    0.11
# feature_level_avg_kg_hits          0.10                   -0.03
# feature_level_sum_kg_hits          0.10                   -0.03
# norm_path_length                   0.15                    0.13
# correlation                        0.16                    0.10
# F.Split-Lift (y==1)                0.16                   -0.13
# Plausible/Makes Sense?             0.46                    1.00
# Interesting?                       1.00                    0.46

# %%
def get_examples(data,target,get_interesting=True,get_plausible=True,print_plausible_prompt=False):
    results = []

    novel_prompts = []
    plausible_prompts = []
    for index, row in tqdm(data.iterrows(), total=data.shape[0], desc="Processing rows"):
        feature_name = row['feature_name']
        target = row['Target'].replace(r"\(\)","").replace(" AND "," ").replace(r"(","").replace(r")","")
        # target = "Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis"
        p_val = row['p_val']
        feature_importance = row['feature_importance']
        correlation = row['correlation']
        ## related to biomedical and healthcare disease understanding, prognosis, research, and prediction of:
        prompt_interesting = f"""Given the feature '{feature_name}'; (p-value: {p_val}, correlation: {correlation}, SHAP importance {feature_importance}), as a potential predictive feature, or risk/protective factor for target disease: '{target}', is this feature Novel and interesting?
       \Output Yes or No prediction""" #,then explain why for a medical expert."""
        
        prompt_plausible = f"""Given the feature '{feature_name}'; (p-value: {p_val}, correlation: {correlation}, SHAP importance {feature_importance}), as a potential predictive feature, or risk/protective factor for target disease:'{target}',
        does this feature make sense? Is there a plausible mechanism for the feature to affect the target?\
        Output Yes or No prediction""" #, then explain for a medical expert.
        
        if print_plausible_prompt:
            print(prompt_plausible)
            print()

        novel_prompts.append(prompt_interesting)
        plausible_prompts.append(prompt_plausible)
    
    assert len(novel_prompts)==len(plausible_prompts) ## Doesn't check for nans or empty
    return novel_prompts,plausible_prompts

        ## following part was used for making training examples or ICL examples ofr GPT. comment out for now !
    #     response_interesting = f"{'Yes' if row['Interesting?'] else 'No'}. {'' if pd.isna(row['COMMENTS']) else row['COMMENTS'].strip()}"

    #     response_plausible = f"{'Yes' if row['Plausible/Makes Sense?'] else 'No'}."
    #     # # if not row['COMMENTS'].str.contains("P value|correlation",case=False,na=False):
    #     # if not row['COMMENTS'].contains("P value|correlation",case=False,na=False):
    #         # response_plausible = response_plausible + f" {row['COMMENTS'].str.strip()}"
    #     # Check if 'COMMENTS' does not contain "P value" or "correlation"
    #     if pd.notna(row['COMMENTS']) and not re.search("P value|correlation", row['COMMENTS'], flags=re.IGNORECASE):
    #         response_plausible += f" {row['COMMENTS'].strip()}"    
    #     if get_interesting:
    #         results.append( {"role": "user", "content":prompt_interesting})
    #         results.append( {"role": "assistant", "content":response_interesting})
    #     if get_plausible:
    #         results.append( {"role": "user", "content":prompt_plausible})
    #         results.append( {"role": "assistant", "content":response_plausible})
    # return results

# %%
novel_prompts,plausible_prompts = get_examples(data,target = "Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis")
# results
# Out:
# Processing rows: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 84/84 [00:00<00:00, 29807.24it/s]

# %%
novel_prompts
# Out:
# ["Given the feature 'Long-standing illness, disability or infirmity Yes'; (p-value: 0.0, correlation: 0.049, SHAP importance 0.041), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Alanine aminotransferase'; (p-value: 0.0, correlation: 0.027, SHAP importance 0.032), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Mouth/teeth dental problems Dentures'; (p-value: 0.0, correlation: 0.031, SHAP importance 0.023), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Overall health rating Fair'; (p-value: 0.0, correlation: 0.043, SHAP importance 0.016), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Standard PRS for alzheimer's disease (AD)'; (p-value: 0.0, correlation: -0.008, SHAP importance 0.012), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Overall health rating Excellent'; (p-value: 0.0, correlation: -0.042, SHAP importance 0.011), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Haemoglobin concentration'; (p-value: 0.0, correlation: -0.014, SHAP importance 0.01), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'SHBG'; (p-value: 0.0, correlation: -0.006, SHAP importance 0.01), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Standing height'; (p-value: 0.0, correlation: -0.041, SHAP importance 0.009), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Gastritis and duodenitis'; (p-value: 0.0, correlation: 0.013, SHAP importance 0.009), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Standard PRS for venous thromboembolic disease (VTE)'; (p-value: 0.002, correlation: 0.007, SHAP importance 0.008), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Townsend deprivation index at recruitment'; (p-value: 0.0, correlation: 0.024, SHAP importance 0.006), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Illnesses of adopted father'; (p-value: 0.035, correlation: 0.004, SHAP importance 0.0), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Hot drink temperature Hot'; (p-value: 0.003, correlation: 0.005, SHAP importance 0.001), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Alcohol drinker status Current'; (p-value: 0.0, correlation: 0.002, SHAP importance 0.002), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Contra-indications for spirometry'; (p-value: 0.0, correlation: -0.005, SHAP importance 0.003), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Salt added to food Never/rarely'; (p-value: 0.0, correlation: 0.012, SHAP importance 0.003), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Year immigrated to UK (United Kingdom)'; (p-value: 0.0, correlation: -0.005, SHAP importance 0.003), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Job code at visit'; (p-value: 0.0, correlation: 0.005, SHAP importance 0.017), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Neuroticism score'; (p-value: 0.902, correlation: -0.007, SHAP importance 0.003), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'dietary changes in the last 5 years Yes, because of other reasons'; (p-value: 0.0, correlation: 0.003, SHAP importance 0.003), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Variation in diet Never/rarely'; (p-value: 0.0, correlation: -0.004, SHAP importance 0.002), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Z51.5 - Palliative care'; (p-value: 0.0, correlation: -0.003, SHAP importance 0.061), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Alcohol intake frequency. Three or four times a week'; (p-value: 0.0, correlation: 0.004, SHAP importance 0.021), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Wheeze or whistling in the chest in last year'; (p-value: 0.0, correlation: 0.004, SHAP importance 0.002), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Time spent outdoors in winter'; (p-value: 0.117, correlation: 0.001, SHAP importance 0.002), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Alcohol intake frequency. Daily or almost daily'; (p-value: 0.0, correlation: -0.006, SHAP importance 0.044), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Alcohol intake frequency. Special occasions only'; (p-value: 0.0, correlation: 0.002, SHAP importance 0.014), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Average Diameter for HDL Particles'; (p-value: 0.0, correlation: 0.001, SHAP importance 0.011), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Apolipoprotein A Blood biochemistry'; (p-value: 0.0, correlation: 0.001, SHAP importance 0.009), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Genetic risk for epithelial ovarian cancer (EOC)'; (p-value: 0.12, correlation: -0.004, SHAP importance 0.008), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Time spend outdoors in summer'; (p-value: 0.0, correlation: 0.007, SHAP importance 0.003), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Z92.2 - Personal history of long-term (current) use of other medicaments'; (p-value: 0.816, correlation: 0.001, SHAP importance 0.003), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Genetic risk for age-related macular degeneration (AMD)'; (p-value: 0.018, correlation: -0.003, SHAP importance 0.002), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Irritability'; (p-value: 0.0, correlation: -0.001, SHAP importance 0.002), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Apolipoprotein A1'; (p-value: 0.0, correlation: 0.006, SHAP importance 0.01), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Total bilirubin'; (p-value: 0.0, correlation: -0.004, SHAP importance 0.01), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Alcohol intake frequency. One to three times a month'; (p-value: 0.0, correlation: 0.001, SHAP importance 0.009), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Diverticulosis'; (p-value: 0.556, correlation: 0.001, SHAP importance 0.007), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Frequency of friend/family visits Almost daily'; (p-value: 0.0, correlation: 0.001, SHAP importance 0.004), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Genetic risk for venous thromboembolic disease (VTE)'; (p-value: 0.054, correlation: 0.001, SHAP importance 0.003), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Genetic risk for parkinson's disease (PD)'; (p-value: 0.506, correlation: -0.003, SHAP importance 0.003), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Other disorders of stomach and duodenum'; (p-value: 0.0, correlation: -0.002, SHAP importance 0.002), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Genetic risk for osteoporosis (OP)'; (p-value: 0.522, correlation: -0.007, SHAP importance 0.002), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Chronic airway obstruction'; (p-value: 0.004, correlation: 0.005, SHAP importance 0.002), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Genetic risk for atrial fibrillation (AF)'; (p-value: 0.136, correlation: -0.003, SHAP importance 0.002), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Skin colour Brown'; (p-value: 0.002, correlation: -0.001, SHAP importance 0.001), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Tea intake'; (p-value: 0.274, correlation: -0.004, SHAP importance 0.001), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Job code at visit nurses'; (p-value: 0.082, correlation: 0.009, SHAP importance 0.001), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Job code at visit managers'; (p-value: 0.0, correlation: -0.004, SHAP importance 0.001), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Leg fat-free mass'; (p-value: 0.018, correlation: -0.006, SHAP importance 0.024), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Sleep - Overall average'; (p-value: 0.012, correlation: 0.012, SHAP importance 0.014), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Genetic risk for coeliac disease (CED)'; (p-value: 0.239, correlation: -0.002, SHAP importance 0.009), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Genetic risk for coronary artery disease (CAD)'; (p-value: 0.954, correlation: -0.005, SHAP importance 0.008), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Skin colour Black'; (p-value: 0.0, correlation: 0.002, SHAP importance 0.007), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Testosterone'; (p-value: 0.0, correlation: -0.005, SHAP importance 0.007), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Genetic risk for bipolar disorder'; (p-value: 0.037, correlation: -0.004, SHAP importance 0.006), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Genetic risk for intraocular pressure'; (p-value: 0.791, correlation: 0.007, SHAP importance 0.004), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Home area population density - urban or rural England/Wales - Village - less sparse'; (p-value: 0.0, correlation: 0.004, SHAP importance 0.004), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Genetic risk for intraocular pressure (IOP)'; (p-value: 0.791, correlation: 0.007, SHAP importance 0.004), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Genetic risk for prostate cancer (PC)'; (p-value: 0.258, correlation: -0.001, SHAP importance 0.004), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Genetic risk for age at menopause (AAM)'; (p-value: 0.026, correlation: 0.006, SHAP importance 0.004), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Genetic risk for bowel cancer (CRC)'; (p-value: 0.259, correlation: 0.003, SHAP importance 0.004), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Enhanced Genetic risk for height'; (p-value: 0.931, correlation: 0.004, SHAP importance 0.003), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Basophill percentage'; (p-value: 0.568, correlation: -0.006, SHAP importance 0.003), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Enhanced Genetic risk for height (HEIGHT)'; (p-value: 0.931, correlation: 0.004, SHAP importance 0.003), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Average Diameter for VLDL Particles'; (p-value: 0.0, correlation: 0.002, SHAP importance 0.003), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Job code at visit industrial'; (p-value: 0.0, correlation: -0.006, SHAP importance 0.003), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Microalbumin in urine'; (p-value: 0.123, correlation: 0.009, SHAP importance 0.003), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Genetic risk for primary open angle glaucoma'; (p-value: 0.095, correlation: -0.002, SHAP importance 0.002), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Concentration of IDL Particles'; (p-value: 0.019, correlation: 0.006, SHAP importance 0.002), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Genetic risk for systemic lupus erythematosus (SLE)'; (p-value: 0.28, correlation: -0.002, SHAP importance 0.002), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Genetic risk for primary open angle glaucoma (POAG)'; (p-value: 0.095, correlation: -0.002, SHAP importance 0.002), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Concentration of HDL Particles'; (p-value: 0.0, correlation: 0.004, SHAP importance 0.002), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Alcohol-related disorders'; (p-value: 0.051, correlation: 0.001, SHAP importance 0.002), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Alcohol intake frequency. Never'; (p-value: 0.0, correlation: -0.002, SHAP importance 0.002), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Genetic risk for psoriasis (PSO)'; (p-value: 0.322, correlation: -0.001, SHAP importance 0.002), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Qualifications College or University degree|A levels/AS levels or equivalent|O levels/GCSEs or equivalent'; (p-value: 0.0, correlation: -0.003, SHAP importance 0.002), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Circulatory disease NEC'; (p-value: 0.523, correlation: 0.008, SHAP importance 0.001), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature '3-Hydroxybutyrate'; (p-value: 0.306, correlation: -0.002, SHAP importance 0.001), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Hallux valgus (Bunion)'; (p-value: 0.095, correlation: 0.0, SHAP importance 0.001), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Cholesterol in Chylomicrons and Extremely Large VLDL'; (p-value: 0.0, correlation: 0.002, SHAP importance 0.001), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Job code at visit clerks'; (p-value: 0.08, correlation: -0.003, SHAP importance 0.001), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction",
#  "Given the feature 'Other diseases of respiratory system, NEC'; (p-value: 0.303, correlation: -0.002, SHAP importance 0.001), as a potential predictive feature, or risk/protective factor for target disease: 'Cholelithiasis OR Gallstones OR Gallbladder disease OR cholecystitis OR Cholangitis', is this feature Novel and interesting?\n       \\Output Yes or No prediction"]

# %%
# %%time
# novel_res = []
# for i in novel_prompts[0:5]:
#     novel_res.append(llm(i, max_tokens=64)['choices'][0]['text'])
# novel_res

# %% [markdown]
# ### Let's try a naive embedding + train a model on that
# * MTEB sota lb are mostly instruct tuned embedder oriented. Hope it won't mess this up.
# * Could use the llama models for text gen, but for a pure number - maybe easier to get embeds (faster than finetuning)
#
# * https://huggingface.co/Alibaba-NLP/gte-Qwen2-7B-instruct
#     * Lots of files?
# * https://huggingface.co/bijaygurung/stella_en_400M_v5
#     * Smaller model. More instruct tuning seemingly?
# * https://huggingface.co/spaces/mteb/leaderboard
#
#
# Could try SetFit finetuning? (Few shot learning)
# * https://huggingface.co/blog/setfit
# * https://huggingface.co/docs/setfit/quickstart

# %%
# 

# ## https://huggingface.co/Alibaba-NLP/gte-Qwen2-7B-instruct
# model = SentenceTransformer("Alibaba-NLP/gte-Qwen2-7B-instruct", trust_remote_code=True ) # enabled originally
# # In case you want to reduce the maximum length:
# model.max_seq_length = 4096#8192

# queries = [
#     "how much protein should a female eat",
#     "summit define",
# ]
# documents = [
#     "As a general guideline, the CDC's average requirement of protein for women ages 19 to 70 is 46 grams per day. But, as you can see from this chart, you'll need to increase that if you're expecting or training for a marathon. Check out the chart below to see how much protein you should be eating each day.",
#     "Definition of summit for English Language Learners. : 1  the highest point of a mountain : the top of a mountain. : 2  the highest level. : 3  a meeting or series of meetings between the leaders of two or more governments.",
# ]

# query_embeddings = model.encode(queries, prompt_name="query")
# document_embeddings = model.encode(documents)

# scores = (query_embeddings @ document_embeddings.T) * 100
# print(scores.tolist())

# %%
from sentence_transformers import SentenceTransformer

# # This model supports two prompts: "s2p_query" and "s2s_query" for sentence-to-passage and sentence-to-sentence tasks, respectively.
# # They are defined in `config_sentence_transformers.json`
# query_prompt_name = "s2p_query"
# queries = [
#     "What are some ways to reduce stress?",
#     "What are the benefits of drinking green tea?",
# ]
# # docs do not need any prompts
# docs = [
#     "There are many effective ways to reduce stress. Some common techniques include deep breathing, meditation, and physical activity. Engaging in hobbies, spending time in nature, and connecting with loved ones can also help alleviate stress. Additionally, setting boundaries, practicing self-care, and learning to say no can prevent stress from building up.",
#     "Green tea has been consumed for centuries and is known for its potential health benefits. It contains antioxidants that may help protect the body against damage caused by free radicals. Regular consumption of green tea has been associated with improved heart health, enhanced cognitive function, and a reduced risk of certain types of cancer. The polyphenols in green tea may also have anti-inflammatory and weight loss properties.",
# ]

# # ！The default dimension is 1024, if you need other dimensions, please clone the model and modify `modules.json` to replace `2_Dense_1024` with another dimension, e.g. `2_Dense_256` or `2_Dense_8192` !
# # on gpu
# model = SentenceTransformer("dunzhang/stella_en_400M_v5", trust_remote_code=True)#.cuda() # needs xformers
# # you can also use this model without the features of `use_memory_efficient_attention` and `unpad_inputs`. It can be worked in CPU.
# # model = SentenceTransformer(
# #     "dunzhang/stella_en_400M_v5",
# #     trust_remote_code=True,
# #     device="cpu",
# #     config_kwargs={"use_memory_efficient_attention": False, "unpad_inputs": False}
# # )
# query_embeddings = model.encode(queries, prompt_name=query_prompt_name)
# doc_embeddings = model.encode(docs)
# print(query_embeddings.shape, doc_embeddings.shape)
# # (2, 1024) (2, 1024)
# similarities = model.similarity(query_embeddings, doc_embeddings)

# %%
# model = SentenceTransformer("BAAI/bge-small-en-v1.5", trust_remote_code=True)#.cuda()
model = SentenceTransformer("BAAI/bge-base-en-v1.5", trust_remote_code=True) #  53,66 auc (Without features)
# model = SentenceTransformer("FremyCompany/BioLORD-2023")

# model = SentenceTransformer("Alibaba-NLP/gte-large-en-v1.5", trust_remote_code=True)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression,LogisticRegressionCV
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_auc_score
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import RocCurveDisplay
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.impute import SimpleImputer

# %%
# %%time
X = model.encode(novel_prompts)
X.shape

# %%
display(data.select_dtypes(["number"])) # Lacks mos useful metadata like path length

# %%
# X = np.hstack([X,data.select_dtypes(["number"]).fillna(-0.1)]) ## Massively boost performance
X = np.hstack([X,data.select_dtypes(["number"])]) #keep nans - if rf
# from 53,67 (w'BAAI/bge-base-en-v1.5) to 61, 74 auc  (with basic min feats)
print(X.shape)

# %%
# clf = LogisticRegressionCV()
# clf = LogisticRegression()
# clf = make_pipeline(StandardScaler(),SimpleImputer(add_indicator=True), LogisticRegression())
clf = RandomForestClassifier(400, min_samples_split=3, min_samples_leaf=3,ccp_alpha=0.015) ## 60, 66 (with extra feats; max)
# clf = KNeighborsClassifier().8

# %%
print("Novel")
y_novel = data["Interesting?"].astype(int)
y_novel_pred = cross_val_predict(clf,X,y_novel)
y_proba = cross_val_predict(clf,X,y_novel,method="predict_proba")[:,1]
print(classification_report(y_novel,y_novel_pred))
print("rocAUC",round(roc_auc_score(y_novel,y_proba),3))

# %%
RocCurveDisplay.from_predictions( y_novel,y_proba,plot_chance_level=True)

# %%
print("Plausible")
y_plausible = data["Plausible/Makes Sense?"].astype(int)
y_plausible_pred = cross_val_predict(clf,X,y_plausible)
print(classification_report(y_plausible,y_plausible_pred))
y_proba = cross_val_predict(clf,X,y_novel,method="predict_proba")[:,1]

print("rocAUC",round(roc_auc_score(y_plausible,y_proba),3))
RocCurveDisplay.from_predictions( y_plausible,y_proba,plot_chance_level=True)
