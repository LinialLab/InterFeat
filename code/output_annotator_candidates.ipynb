# %% [markdown]
# * Positive, final candidates taken from : `ExtraFilterRerank-llmOutputs.ipynb`
#   ```
#    df = df.loc[(df['answer'])| (df[['novel','plausible']].min(axis=1)>0)]
#     df = df.loc[(df['p_val']<=0.3)| ((df['MutualInfoTarget']>=0.003) & (df['feature_importance']>=0.003))]
#
#     clean_feats = deduplicate_texts(df["raw_name"], use_difflib=True, string_cutoff=0.95, distance_threshold=0.8)
#   ```

# %%
import pandas as pd
from configs import *

# %%
# !conda install openpyxl -y

# %%
def corr_direction(row):
    corr = row['corr']

    # Determine direction of effect
    if corr > 0:
        direction = 'positive'
    elif corr < 0:
        direction = 'negative'
    else:
        direction = 'neutral'
    return direction

import pandas as pd
from openpyxl import load_workbook
from openpyxl.worksheet.datavalidation import DataValidation

def prepare_annotation_sheet(input_df, output_file, annotation_columns={
                                       "Novel": "numeric",
                                       "Plausible/Makes Sense": "numeric",
                                        "Utility": "numeric",
                                       "Interesting": "numeric",
                                   }):
    """
    Prepares an Excel sheet for human annotation with data types validation.

    Args:
        input_df (pd.DataFrame): The input dataframe with base data.
        output_file (str): Path to save the Excel file.
        annotation_columns (dict): Dictionary where keys are column names 
                                   and values are validation types. 
                                   Example:
                                   {
                                       "Novel": "boolean",
                                       "Plausible": "boolean",
                                       "Interesting": "numeric",
                                       "Utility": "boolean"
                                   }

    Returns:
        None: Saves the Excel file with data validation applied.
    """
    # Save the dataframe to an Excel file
    input_df.to_excel(output_file, index=False, engine="openpyxl")

    # Load the workbook to add Excel logic
    wb = load_workbook(output_file)
    ws = wb.active

    # Add annotation columns with validation
    col_index = len(input_df.columns) + 1  # Starting index for annotation columns
    for col_name, validation_type in annotation_columns.items():
        # Add column header
        ws.cell(row=1, column=col_index, value=col_name)

        # Define data validation
        if validation_type == "boolean":
            validation = DataValidation(type="list", formula1='"True,False"', showDropDown=False, allow_blank=True)
        elif validation_type == "numeric":
            # validation = DataValidation(type="whole", operator="between", formula1="1", formula2="4")
            validation = DataValidation(
                type="list", 
                formula1='"1,2,3,4"', 
                # showDropDown=True,
                showDropDown=False,
                allow_blank=True,
            )
        else:
            raise ValueError(f"Unsupported validation type: {validation_type}")
        validation.showInputMessage = True
        validation.showErrorMessage = True
        validation.error = 'Invalid input: Please choose a value between 1-4.'
        validation.errorTitle = 'Invalid Entry'
        validation.errorStyle = 'stop'         # or 'warning' / 'information'
        validation.showErrorMessage = True
        # Add validation to the column
        for row in range(2, len(input_df) + 2):  # Assuming headers are in the first row
            validation.add(ws.cell(row=row, column=col_index))

        # Add the validation rule to the worksheet
        ws.add_data_validation(validation)

        col_index += 1

    # Save the updated workbook
    wb.save(output_file)
    print(f"Excel sheet with annotation logic saved to {output_file}.")

# %%
## import from configs
all_configs = [config_gall,
               config_celiac, config_gout,config_spine, config_oesophagus, config_eye_occ,config_depression,
    config_heart
              ]

MAX_FINAL_CANDIDATES = 50

# %%
for config in all_configs:
    print(config['OUTPUT_RES_PREFIX'])
    
    df_pos = pd.read_csv(f"./Outputs/llm_reranked/subset/"+config['OUTPUT_RES_PREFIX']+"_ranked.csv")
    num_pos = df_pos.shape[0]
    print(num_pos,"# Positive candidates (pre limit)")
    df_pos = df_pos.head(MAX_FINAL_CANDIDATES)
    df_pos.rename(columns={'step_by_step_explanation':"explanation","target":'Target'},inplace=True) 
    df_pos["Real"] = 1

    df_neg = pd.read_csv(f"./Outputs/Negatives+Explain/neg_explanations-{config.get('OUTPUT_RES_PREFIX', '')}.csv")
    ## get 20% of real cases as negaitves:
    df_neg = df_neg.head(num_pos//5)
    df_neg.drop(columns=["feature_name","prompt"],inplace=True,errors="ignore")
    df_neg["Feature_Name"] = df_neg["raw_name"]
    df_neg["Real"] = 0
    
    # display(df_pos.head(2))
    # display(df_neg.head(2).select_dtypes("O"))

    df = pd.concat([df_pos,df_neg],ignore_index=True).sample(frac=1)
    df["Target"] = df["Target"].str.replace("AND","")
    df["correlation"] = df.apply(corr_direction,axis=1)
    df.to_csv(f"./Outputs/for_annotators/uncensored/{config['OUTPUT_RES_PREFIX']}candidates_uncensored.csv")
    df = df[['Feature_Name','explanation', "correlation",'Target']]
    df["Comments"] = ""
 
    # df.to_csv(f"./Outputs/for_annotators/raw/{config['OUTPUT_RES_PREFIX']}candidates_uncensored.csv")

    prepare_annotation_sheet(input_df=df, output_file=f"./Outputs/for_annotators/{config['OUTPUT_RES_PREFIX']}candidates.xlsx"
                             ,
                             annotation_columns={
                                           "Novel?": "numeric",
                                           "Plausible-Makes sense?": "numeric",
                                            "Utility?": "numeric",
                                           "Interesting?": "numeric",
                                       })
    display(df)
# Out:
# gallstone_
# 43 # Positive candidates (pre limit)
# Excel sheet with annotation logic saved to ./Outputs/for_annotators/gallstone_candidates.xlsx.
#                                          Feature_Name  \
# 28                     missing_Essential hypertension
# 17  Home area population density - urban or rural_...
# 35                              Skin colour_Very fair
# 45                                  Actinic keratosis
# 3   Frequency of tiredness / lethargy in last 2 we...
# 1                 Apolipoprotein A Blood biochemistry
# 24                    (BC) breast cancer genetic risk
# 26                                    Sodium in urine
# 40                          Cholesterol in Medium HDL
# 30                          (AST) asthma genetic risk
# 0        Major dietary changes in the last 5 years_No
# 4                      (HT) hypertension genetic risk
# 5                  (CED) coeliac disease genetic risk
# 8        (HBA1C_DF) glycated haemoglobin genetic risk
# 39  Medication for cholesterol, blood pressure, di...
# 2        Number of self-reported non-cancer illnesses
# 38                                               SHBG
# 21                          Arm fat percentage (left)
# 37         (CAD) coronary artery disease genetic risk
# 36  Complications of cardiac/vascular device, impl...
# 41                      LDL direct Blood biochemistry
# 6   A09.9 - Gastroenteritis and colitis of unspeci...
# 15  (LDL_SF) low density lipoprotein cholesterol g...
# 22                                          Vitamin D
# 13                            Sleep - Overall average
# 23              (AD) alzheimer's disease genetic risk
# 14                   (SCZ) schizophrenia genetic risk
# 20  Started insulin within one year diagnosis of d...
# 29           Bipolar and major depression status_None
# 44       Z90.7 - Acquired absence of genital organ(s)
# 34                          Other specified gastritis
# 19          Townsend deprivation index at recruitment
# 32    Treatment/medication code | Array 0__omeprazole
# 25                (AAM) age at menopause genetic risk
# 50                  M79.66 - Pain in limb (Lower leg)
# 33                                            Acetone
# 47   Ever addicted to a behaviour or miscellanous_Yes
# 18                    Time spend outdoors in summer_2
# 7                                             Acetate
# 46          Epilepsy, recurrent seizures, convulsions
# 49  Behavioural and miscellaneous addictions_Somet...
# 42                (ISS) ischaemic stroke genetic risk
# 31    (POAG) primary open angle glaucoma genetic risk
# 48  Behavioural and miscellaneous addictions_A beh...
# 16                                Fed-up feelings_Yes
# 9              (RA) rheumatoid arthritis genetic risk
# 11          Concentration of Very Large HDL Particles
# 43                Degeneration of intervertebral disc
# 27                                  Neuroticism score
# 10         Concentration of Very Large VLDL Particles
# 12        Apolipoprotein B to Apolipoprotein A1 ratio
#
#                                           explanation correlation  \
# 28  The feature 'Essential hypertension' has a neg...    negative
# 17  1. **Novelty:** The feature 'Home area populat...    negative
# 35  The feature 'Skin colour Very fair' is conside...    positive
# 45  Actinic keratosis is interesting because it ha...    positive
# 3   1. **Novelty:** The feature 'Frequency of tire...    positive
# 1   The feature 'Apolipoprotein A Blood biochemist...    negative
# 24  The feature 'BC breast cancer genetic risk' be...    positive
# 26  The feature 'Sodium in urine' is evaluated for...    positive
# 40  The feature 'Cholesterol in Medium HDL' is eva...    negative
# 30  1. **Novelty:** The association between asthma...    positive
# 0   The feature 'dietary changes in the last 5 yea...    negative
# 4   1. **Novelty:** The association between hypert...    positive
# 5   The feature '(CED) coeliac disease genetic ris...    positive
# 8   The feature 'HBA1C DF glycated haemoglobin gen...    positive
# 39  1. **Novelty:** The association between blood ...    positive
# 2   The feature 'Number of self-reported non-cance...    positive
# 38  The feature 'SHBG' (Sex Hormone Binding Globul...    negative
# 21  1. **Novelty:** The relationship between arm f...    positive
# 37  The feature 'CAD coronary artery disease genet...    negative
# 36  The feature 'Complications of cardiac vascular...    positive
# 41  The feature 'LDL direct Blood biochemistry' be...    negative
# 6   1. **Novelty:** The association between 'A09.9...    positive
# 15  The feature 'LDL SF' low density lipoprotein c...    negative
# 22  The feature 'Vitamin D' in relation to gallbla...    negative
# 13  1. **Novelty:** The relationship between sleep...    positive
# 23  The feature 'AD Alzheimer's disease genetic ri...    negative
# 14  The feature 'SCZ schizophrenia genetic risk' i...    negative
# 20  The feature 'Started insulin within one year d...    positive
# 29  The feature 'Bipolar and major depression stat...    positive
# 44  The feature 'Z90.7 - Acquired absence of genit...    positive
# 34  The feature 'Other specified gastritis' is eva...    positive
# 19  The Townsend deprivation index is a well-estab...    positive
# 32  The feature 'medication omeprazole' in relatio...    positive
# 25  The feature '(AAM) age at menopause genetic ri...    negative
# 50  The feature 'M79.66 - Pain in limb (Lower leg)...    positive
# 33  The feature 'Acetone' is evaluated for its rel...    negative
# 47  The feature 'Ever addicted to a behaviour or m...    negative
# 18  1. **Novelty:** The feature 'Time spend outdoo...    negative
# 7   The feature 'Acetate' is not typically associa...    negative
# 46  The feature 'Epilepsy, recurrent seizures, con...    positive
# 49  The feature 'Behavioural and miscellaneous add...    positive
# 42  The feature 'ischaemic stroke genetic risk' (I...    positive
# 31  The feature 'POAG primary open angle glaucoma ...    negative
# 48  The feature 'Behavioural and miscellaneous add...     neutral
# 16  The feature 'Fed up feelings' is evaluated bas...    positive
# 9   The feature 'RA genetic risk' in relation to g...    positive
# 11  The feature 'Concentration of Very Large HDL P...    negative
# 43  The feature 'Degeneration of intervertebral di...    positive
# 27  1. **Novelty:** The association between neurot...    positive
# 10  The feature 'Concentration of Very Large VLDL ...    positive
# 12  1. **Novelty:** The association between the Ap...    positive
#
#                                                Target Comments
# 28  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 17  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 35  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 45  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 3   (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 1   (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 24  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 26  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 40  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 30  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 0   (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 4   (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 5   (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 8   (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 39  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 2   (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 38  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 21  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 37  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 36  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 41  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 6   (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 15  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 22  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 13  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 23  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 14  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 20  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 29  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 44  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 34  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 19  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 32  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 25  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 50  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 33  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 47  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 18  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 7   (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 46  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 49  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 42  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 31  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 48  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 16  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 9   (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 11  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 43  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 27  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 10  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# 12  (Cholelithiasis) OR (Gallstone) OR (Gallbladde...
# celiac_
# 49 # Positive candidates (pre limit)
# Excel sheet with annotation logic saved to ./Outputs/for_annotators/celiac_candidates.xlsx.
#                                          Feature_Name  \
# 46                     Concentration of HDL Particles
# 28  missing_Z90.4 - Acquired absence of other part...
# 30               Falls in the last year_Only one fall
# 44                     Cholesterol in Very Small VLDL
# 24                           missing_Direct bilirubin
# 50                             Hallux valgus (Bunion)
# 23                                            Acetone
# 48                     Variation in diet_Never/rarely
# 2   Home area population density - urban or rural_...
# 56   Z98.0 - Intestinal bypass and anastomosis status
# 12  Treatment/medication code | Array 0__entry unable
# 18  (EBMDT) estimated bone mineral density t-score...
# 10                                  Neuroticism score
# 20                                 Potassium in urine
# 35                                   Apolipoprotein B
# 26                        (MEL) melanoma genetic risk
# 51  Ever addicted to illicit or recreational drugs...
# 1                    Triglycerides Blood biochemistry
# 8                 (AAM) age at menopause genetic risk
# 33  (AMD) age-related macular degeneration genetic...
# 41                                 Cholesterol in IDL
# 37                            missing_Arthropathy NOS
# 9               Concentration of Medium HDL Particles
# 5                           (AST) asthma genetic risk
# 52  Ever addicted to illicit or recreational drugs...
# 22  Mental health conditions ever diagnosed by a p...
# 57                      Hemorrhage of rectum and anus
# 34    Treatment/medication code | Array 0__amlodipine
# 3                                     Sodium in urine
# 54  Doctor diagnosed alpha-1 antitrypsin deficienc...
# 21  (HDL) high density lipoprotein cholesterol gen...
# 45                                    Weight (p21002)
# 36                                            Alanine
# 0                                                SHBG
# 40  Complications of transplants and reattached limbs
# 13                       (PSO) psoriasis genetic risk
# 47                            Total protein aliquot_1
# 4         Apolipoprotein B to Apolipoprotein A1 ratio
# 11                 HDL cholesterol Blood biochemistry
# 29   Treatment/medication code | Array 0__simvastatin
# 15  Blood clot, DVT, bronchitis, emphysema, asthma...
# 16  Home area population density - urban or rural_...
# 38              Concentration of Small VLDL Particles
# 32                     Hearing difficulty/problems_No
# 42  Frequency of depressed mood in last 2 weeks_No...
# 39             Concentration of Medium VLDL Particles
# 7                              Oily fish intake_Never
# 27       (HBA1C_DF) glycated haemoglobin genetic risk
# 25               Concentration of Small HDL Particles
# 49  Eye problems/disorders_Injury or trauma result...
# 6   Had other major operations_Yes - you will be a...
# 43                               Syncope and collapse
# 53     Age macular degeneration diagnosed_infrequent_
# 17         Concentration of Very Small VLDL Particles
# 14                                  Apolipoprotein A1
# 31          Time spent outdoors in winter_Do not know
# 19                                  3-Hydroxybutyrate
# 55                              Anal and rectal polyp
#
#                                           explanation correlation  \
# 46  1. **Novelty:** The relationship between HDL p...    negative
# 28  The feature 'Z90.4 - Acquired absence of other...    negative
# 30  The feature 'Falls in the last year Only one f...    positive
# 44  The feature 'Cholesterol in Very Small VLDL' i...    negative
# 24  1. **Novelty:** The association between direct...    positive
# 50  The feature 'Hallux valgus (Bunion)' is intere...    negative
# 23  The feature 'Acetone' is evaluated for its pot...    negative
# 48  The feature 'Variation in diet Never/rarely' i...    positive
# 2   The feature 'Home area population density - ur...    negative
# 56  The feature 'Z98.0 - Intestinal bypass and ana...    negative
# 12  The feature 'medication entry unable' is novel...    positive
# 18  The feature 'EBMDT estimated bone mineral dens...    negative
# 10  The feature 'Neuroticism score' is interesting...    positive
# 20  1. **Novelty:** The association between urinar...    negative
# 35  1. **Novelty:** The association between Apolip...    negative
# 26  1. **Novelty:** The association between melano...    negative
# 51  Ever addicted to illicit or recreational drugs...    negative
# 1   The feature 'Triglycerides Blood biochemistry'...    negative
# 8   The feature '(AAM) age at menopause genetic ri...    negative
# 33  The feature 'AMD genetic risk' in relation to ...    positive
# 41  The feature 'Cholesterol in IDL' has a negativ...    negative
# 37  The feature 'Arthropathy NOS' in relation to p...    negative
# 9   The feature 'Concentration of Medium HDL Parti...    negative
# 5   The evaluation of the feature '(AST) asthma ge...    positive
# 52  This feature is interesting because it highlig...    negative
# 22  The feature 'Mental health conditions ever dia...    negative
# 57  The feature 'Hemorrhage of rectum and anus' is...    negative
# 34  1. **Novelty:** The association between amlodi...    negative
# 3   1. **Novelty:** The association between sodium...    negative
# 54  The feature 'Doctor diagnosed alpha-1 antitryp...    negative
# 21  The feature 'HDL high density lipoprotein chol...    negative
# 45  The feature 'Weight (p21002)' has a negative c...    negative
# 36  1. **Novelty:** The association of alanine wit...    positive
# 0   1. **Novelty:** SHBG is not commonly linked to...    positive
# 40  The feature 'Complications of transplants and ...    negative
# 13  The feature 'PSO psoriasis genetic risk' is ev...    negative
# 47  1. **Novelty:** The feature 'Total protein ali...    positive
# 4   The feature 'Apolipoprotein B to Apolipoprotei...    positive
# 11  The feature 'HDL cholesterol Blood biochemistr...    negative
# 29  1. **Novelty:** The association between simvas...    negative
# 15  The feature 'Blood clot, DVT, bronchitis, emph...    negative
# 16  The feature 'Home area population density - ur...    negative
# 38  The feature 'Concentration of Small VLDL Parti...    negative
# 32  The feature 'Hearing difficulty problems' in r...    negative
# 42  The feature 'Frequency of depressed mood in la...    negative
# 39  The feature 'Concentration of Medium VLDL Part...    negative
# 7   1. **Novelty:** The feature 'Oily fish intake ...    positive
# 27  The feature 'HBA1C DF glycated haemoglobin gen...    positive
# 25  1. **Novelty:** The feature 'Concentration of ...    negative
# 49  This feature is interesting because it suggest...    negative
# 6   The feature 'Had other major operations Yes - ...    positive
# 43  The feature 'Syncope and collapse' is not typi...    positive
# 53  The feature 'Age macular degeneration diagnose...    negative
# 17  The feature 'Concentration of Very Small VLDL ...    negative
# 14  The feature 'Apolipoprotein A1' is interesting...    negative
# 31  The feature 'Time spent outdoors in winter' is...    negative
# 19  1. **Novelty:** The association between 3-Hydr...    negative
# 55  Interestingness: The feature 'Anal and rectal ...    negative
#
#                                                Target Comments
# 46  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 28  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 30  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 44  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 24  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 50  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 23  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 48  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 2   (celiac  disease) OR (Coeliac) OR (gluten  all...
# 56  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 12  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 18  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 10  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 20  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 35  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 26  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 51  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 1   (celiac  disease) OR (Coeliac) OR (gluten  all...
# 8   (celiac  disease) OR (Coeliac) OR (gluten  all...
# 33  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 41  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 37  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 9   (celiac  disease) OR (Coeliac) OR (gluten  all...
# 5   (celiac  disease) OR (Coeliac) OR (gluten  all...
# 52  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 22  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 57  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 34  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 3   (celiac  disease) OR (Coeliac) OR (gluten  all...
# 54  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 21  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 45  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 36  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 0   (celiac  disease) OR (Coeliac) OR (gluten  all...
# 40  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 13  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 47  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 4   (celiac  disease) OR (Coeliac) OR (gluten  all...
# 11  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 29  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 15  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 16  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 38  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 32  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 42  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 39  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 7   (celiac  disease) OR (Coeliac) OR (gluten  all...
# 27  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 25  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 49  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 6   (celiac  disease) OR (Coeliac) OR (gluten  all...
# 43  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 53  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 17  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 14  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 31  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 19  (celiac  disease) OR (Coeliac) OR (gluten  all...
# 55  (celiac  disease) OR (Coeliac) OR (gluten  all...
# gout_
# 53 # Positive candidates (pre limit)
# Excel sheet with annotation logic saved to ./Outputs/for_annotators/gout_candidates.xlsx.
#                                          Feature_Name  \
# 25                          Haemoglobin concentration
# 18                      Meat substitutes - vegetarian
# 19             Health satisfaction_Moderately unhappy
# 3                 Average Diameter for VLDL Particles
# 38                (ISS) ischaemic stroke genetic risk
# 37    (POAG) primary open angle glaucoma genetic risk
# 7           Falls in the last year_More than one fall
# 17          Townsend deprivation index at recruitment
# 50               Hemorrhage of gastrointestinal tract
# 32                     Concentration of IDL Particles
# 44                           Irritability_Do not know
# 56       Z90.7 - Acquired absence of genital organ(s)
# 48                     Concentration of HDL Particles
# 41        Apolipoprotein B to Apolipoprotein A1 ratio
# 6        (HBA1C_DF) glycated haemoglobin genetic risk
# 10                   Triglycerides Blood biochemistry
# 14                          Arm fat percentage (left)
# 11                                  3-Hydroxybutyrate
# 53                                Abnormality of gait
# 16  Home area population density - urban or rural_...
# 4                 Surgery/amputation of toe or leg_No
# 5                   Date of all cause dementia report
# 1                               Microalbumin in urine
# 35                 HDL cholesterol Blood biochemistry
# 2               Concentration of Large VLDL Particles
# 39  Vascular/heart problems diagnosed by doctor_Hi...
# 43  Surgery on leg arteries (other than for varico...
# 22  Home area population density - urban or rural_...
# 29                         missing_Cancer of prostate
# 27  (HDL) high density lipoprotein cholesterol gen...
# 9                                 Fed-up feelings_Yes
# 20  Home area population density - urban or rural_...
# 15          Fractured/broken bones in last 5 years_No
# 49  Never eat eggs, dairy, wheat, sugar_I eat all ...
# 40          Concentration of Very Large HDL Particles
# 34                                               SHBG
# 12                   (SCZ) schizophrenia genetic risk
# 24  missing_Z92.1 - Personal history of long-term ...
# 42                    Number of self-reported cancers
# 0        Number of self-reported non-cancer illnesses
# 31                          (AST) asthma genetic risk
# 51                          Abdominal aortic aneurysm
# 55  Z90.4 - Acquired absence of other parts of dig...
# 23  Non-cancer illness code, self-reported | Array...
# 28  Mental health conditions ever diagnosed by a p...
# 46                          Cholesterol in Small VLDL
# 13  Other chronic ischemic heart disease, unspecified
# 21  missing_Complications of transplants and reatt...
# 57          Epilepsy, recurrent seizures, convulsions
# 45               Concentration of Small LDL Particles
# 26               (MS) multiple sclerosis genetic risk
# 30                                          Vitamin D
# 8   Concentration of Chylomicrons and Extremely La...
# 36                        (MEL) melanoma genetic risk
# 59  Ever addicted to illicit or recreational drugs...
# 33                            Had major operations_No
# 58  Ever addicted to illicit or recreational drugs...
# 54                 Cellulitis and abscess of arm/hand
# 52          Abnormal findings on examination of urine
# 47                                 Cholesterol in IDL
#
#                                           explanation correlation Target  \
# 25  1. **Novelty:** The relationship between haemo...    negative   Gout
# 18  1. **Novelty:** The association between 'Meat ...    positive   Gout
# 19  The feature 'Health satisfaction Moderately un...    positive   Gout
# 3   The feature 'Average Diameter for VLDL Particl...    positive   Gout
# 38  The feature '(ISS) ischaemic stroke genetic ri...    positive   Gout
# 37  The feature 'POAG primary open angle glaucoma ...    negative   Gout
# 7   The feature 'Falls in the last year More than ...    positive   Gout
# 17  1. **Novelty:** The Townsend deprivation index...    positive   Gout
# 50  The feature 'Hemorrhage of gastrointestinal tr...    negative   Gout
# 32  The feature 'Concentration of IDL Particles' i...    negative   Gout
# 44  The feature 'Irritability' in relation to pred...    positive   Gout
# 56  Interestingness: Z90.7 - Acquired absence of g...     neutral   Gout
# 48  The feature 'Concentration of HDL Particles' i...    positive   Gout
# 41  The feature 'Apolipoprotein B to Apolipoprotei...    negative   Gout
# 6   The feature 'HBA1C DF glycated haemoglobin gen...    positive   Gout
# 10  The feature 'Triglycerides Blood biochemistry'...    positive   Gout
# 14  The feature 'Arm fat percentage' in relation t...    positive   Gout
# 11  The feature '3-Hydroxybutyrate' in relation to...    positive   Gout
# 53  Abnormality of gait is interesting because it ...    positive   Gout
# 16  The feature 'Home area population density - ur...    negative   Gout
# 4   The feature 'Surgery/amputation of toe or leg'...    positive   Gout
# 5   The feature 'Date of all cause dementia report...    negative   Gout
# 1   The feature 'Microalbumin in urine' presents a...    positive   Gout
# 35  1. **Novelty:** The relationship between HDL c...    negative   Gout
# 2   The feature 'Concentration of Large VLDL Parti...    positive   Gout
# 39  The feature 'Vascular heart problems diagnosed...    positive   Gout
# 43  The feature 'Surgery on leg arteries other tha...    positive   Gout
# 22  The feature 'Home area population density - ur...    negative   Gout
# 29  The feature 'Cancer of prostate' in relation t...    positive   Gout
# 27  The feature 'HDL cholesterol genetic risk' in ...    negative   Gout
# 9   The feature 'Fed up feelings' in relation to p...    positive   Gout
# 20  The feature 'Home area population density - ur...    positive   Gout
# 15  The feature 'Fractured/broken bones in last 5 ...    negative   Gout
# 49  The feature 'Never eat eggs, dairy, wheat, sug...    negative   Gout
# 40  1. **Novelty:** The relationship between very ...    negative   Gout
# 34  1. **Novelty:** The association between SHBG a...    negative   Gout
# 12  The feature 'SCZ schizophrenia genetic risk' i...    negative   Gout
# 24  1. **Novelty:** The association between long-t...    negative   Gout
# 42  The feature 'Number of self-reported cancers' ...    positive   Gout
# 0   The feature 'Number of self-reported non-cance...    positive   Gout
# 31  1. **Novelty:** The association between asthma...    positive   Gout
# 51  The feature 'Abdominal aortic aneurysm' is int...    negative   Gout
# 55  The feature 'Z90.4 - Acquired absence of other...    positive   Gout
# 23  The feature 'Non-cancer illness code, self-rep...    negative   Gout
# 28  The feature 'Mental health conditions ever dia...    negative   Gout
# 46  The feature 'Cholesterol in Small VLDL' and it...    negative   Gout
# 13  The feature 'Other chronic ischemic heart dise...    positive   Gout
# 21  The feature 'Complications of transplants and ...    negative   Gout
# 57  The feature 'Epilepsy, recurrent seizures, con...    negative   Gout
# 45  1. **Novelty:** The feature 'Concentration of ...    negative   Gout
# 26  The feature 'MS multiple sclerosis genetic ris...    positive   Gout
# 30  1. **Novelty:** The association between Vitami...    negative   Gout
# 8   The feature 'Concentration of Chylomicrons and...    positive   Gout
# 36  1. **Novelty:** The association between melano...    positive   Gout
# 59  The feature 'Ever addicted to illicit or recre...    positive   Gout
# 33  The feature 'Had major operations' is negative...    negative   Gout
# 58  The feature 'Ever addicted to illicit or recre...     neutral   Gout
# 54  The feature 'Cellulitis and abscess of arm/han...    positive   Gout
# 52  The feature 'Abnormal findings on examination ...     neutral   Gout
# 47  The feature 'Cholesterol in IDL' shows a negat...    negative   Gout
#
#    Comments
# 25
# 18
# 19
# 3
# 38
# 37
# 7
# 17
# 50
# 32
# 44
# 56
# 48
# 41
# 6
# 10
# 14
# 11
# 53
# 16
# 4
# 5
# 1
# 35
# 2
# 39
# 43
# 22
# 29
# 27
# 9
# 20
# 15
# 49
# 40
# 34
# 12
# 24
# 42
# 0
# 31
# 51
# 55
# 23
# 28
# 46
# 13
# 21
# 57
# 45
# 26
# 30
# 8
# 36
# 59
# 33
# 58
# 54
# 52
# 47
# spine_
# 67 # Positive candidates (pre limit)
# Excel sheet with annotation logic saved to ./Outputs/for_annotators/spine_candidates.xlsx.
#                                          Feature_Name  \
# 33                        Variation in diet_Sometimes
# 51                                            Acetone
# 61                     Alcohol intake frequency._None
# 0   Long-standing illness, disability or infirmity_No
# 52                                  Actinic keratosis
# ..                                                ...
# 9   Major dietary changes in the last 5 years_Yes,...
# 18              Concentration of Large VLDL Particles
# 39            missing_Atrial fibrillation and flutter
# 29                          Cholesterol in Medium LDL
# 59  Behavioural and miscellaneous addictions_A beh...
#
#                                           explanation correlation  \
# 33  1. **Novelty:** The feature 'Variation in diet...    positive
# 51  Interestingness: Acetone levels have been inve...    negative
# 61  ## Step 1: Assess Novelty\nThe feature 'Alcoho...    positive
# 0   The feature 'Long-standing illness, disability...    negative
# 52  The feature 'Actinic keratosis' is interesting...    positive
# ..                                                ...         ...
# 9   The feature 'dietary changes in the last 5 yea...    positive
# 18  The feature 'Concentration of Large VLDL Parti...    positive
# 39  1. **Novelty:** The association between atrial...    negative
# 29  The feature 'Cholesterol in Medium LDL' being ...    negative
# 59  <|assistant>\nThe feature 'Behavioural and mis...    negative
#
#                                                Target Comments
# 33  (disc displacement) OR (disc degeneration) OR ...
# 51  (disc displacement) OR (disc degeneration) OR ...
# 61  (disc displacement) OR (disc degeneration) OR ...
# 0   (disc displacement) OR (disc degeneration) OR ...
# 52  (disc displacement) OR (disc degeneration) OR ...
# ..                                                ...      ...
# 9   (disc displacement) OR (disc degeneration) OR ...
# 18  (disc displacement) OR (disc degeneration) OR ...
# 39  (disc displacement) OR (disc degeneration) OR ...
# 29  (disc displacement) OR (disc degeneration) OR ...
# 59  (disc displacement) OR (disc degeneration) OR ...
#
# [63 rows x 5 columns]
# oesophagus_
# 44 # Positive candidates (pre limit)
# Excel sheet with annotation logic saved to ./Outputs/for_annotators/oesophagus_candidates.xlsx.
#                                          Feature_Name  \
# 14                        (MEL) melanoma genetic risk
# 32                                  Apolipoprotein A1
# 51                            Age asthma diagnosed_10
# 3                                     Weight (p21002)
# 41      Treatment/medication code | Array 0__atenolol
# 24                (ISS) ischaemic stroke genetic risk
# 48  Ever addicted to illicit or recreational drugs...
# 44        Abnormal results of function study of liver
# 35             (RA) rheumatoid arthritis genetic risk
# 37                              Birth weight known_No
# 1           Townsend deprivation index at recruitment
# 23         (CAD) coronary artery disease genetic risk
# 34                                   Apolipoprotein B
# 30                Average Diameter for VLDL Particles
# 27                          (AST) asthma genetic risk
# 8                                             Alanine
# 43          Mouth/teeth dental problems_Bleeding gums
# 49     Age other serious eye condition diagnosed_None
# 46       Z90.7 - Acquired absence of genital organ(s)
# 25   (VTE) venous thromboembolic disease genetic risk
# 18                                            Acetone
# 36                 Mean platelet (thrombocyte) volume
# 29             Age high blood pressure diagnosed_None
# 28  Mineral and other dietary supplements_Glucosamine
# 10  Long-term/recurrent antibiotics as child or te...
# 38                       Doctor diagnosed asthma_None
# 4   Mental health conditions ever diagnosed by a p...
# 40                           Cholesterol in Large LDL
# 0   Non-cancer illness code, self-reported | Array...
# 7        (EOC) epithelial ovarian cancer genetic risk
# 12                     Cholesterol Blood biochemistry
# 11  (LDL_SF) low density lipoprotein cholesterol g...
# 6                                   3-Hydroxybutyrate
# 16          (CVD) cardiovascular disease genetic risk
# 20                      LDL direct Blood biochemistry
# 47  Ever addicted to a behaviour or miscellanous_i...
# 33  Mental health conditions ever diagnosed by a p...
# 31         Concentration of Very Small VLDL Particles
# 13                                               SHBG
# 50                            Age angina diagnosed_48
# 39  Home area population density - urban or rural_...
# 19    (SLE) systemic lupus erythematosus genetic risk
# 42                                      Triglycerides
# 15                       (PSO) psoriasis genetic risk
# 5   Mental health conditions ever diagnosed by a p...
# 22       (HBA1C_DF) glycated haemoglobin genetic risk
# 21                                       Acetoacetate
# 45  Z90.4 - Acquired absence of other parts of dig...
# 26  Wheeze or whistling in the chest in last year_Yes
# 17                                          Vitamin D
# 2                                     Hypotension NOS
# 9                Mouth/teeth dental problems_Dentures
#
#                                           explanation correlation  \
# 14  1. **Novelty:** The association between melano...    positive
# 32  The feature 'Apolipoprotein A1' (ApoA1) in rel...    positive
# 51  The feature 'Age asthma diagnosed_10' is inter...    positive
# 3   The feature 'Weight (p21002)' in relation to o...    positive
# 41  1. **Novelty:** Atenolol is a beta-blocker use...    positive
# 24  1. **Novelty:** The association between ischae...    positive
# 48  The feature 'Ever addicted to illicit or recre...    negative
# 44  **Interestingness:** The feature 'Abnormal res...    negative
# 35  The feature 'RA rheumatoid arthritis genetic r...    positive
# 37  The feature 'Birth weight known' in relation t...    positive
# 1   The Townsend deprivation index is a well-known...    positive
# 23  The feature 'CAD coronary artery disease genet...    negative
# 34  The feature 'Apolipoprotein B' is primarily as...    negative
# 30  The feature 'Average Diameter for VLDL Particl...    positive
# 27  The feature '(AST) asthma genetic risk' in rel...    positive
# 8   The feature 'Alanine' in relation to oesophagu...    negative
# 43  The feature 'Mouth/teeth dental problems_Bleed...    negative
# 49  Interestingness: The feature Age other serious...    negative
# 46  The feature Z90.7 - Acquired absence of genita...    negative
# 25  The feature 'VTE venous thromboembolic disease...    negative
# 18  1. **Novelty:** The association between aceton...    positive
# 36  1. **Novelty:** The relationship between mean ...    negative
# 29  The feature 'Age high blood pressure diagnosed...    negative
# 28  The feature 'Mineral and other dietary supplem...    negative
# 10  The feature 'Long-term/recurrent antibiotics a...    negative
# 38  The feature 'Doctor diagnosed asthma' in relat...    positive
# 4   The feature 'Mental health conditions ever dia...    negative
# 40  1. **Novelty:** The association between choles...    negative
# 0   1. **Novelty:** The association between hypert...    positive
# 7   The feature 'EOC epithelial ovarian cancer gen...    negative
# 12  The feature 'Cholesterol Blood biochemistry' i...    negative
# 11  The feature '(LDL SF) low density lipoprotein ...    negative
# 6   The feature '3-Hydroxybutyrate' is interesting...    positive
# 16  The feature 'CVD cardiovascular disease geneti...    negative
# 20  The feature 'LDL direct Blood biochemistry' is...    negative
# 47  The feature 'Ever addicted to a behavior or mi...    negative
# 33  The feature 'Mental health conditions ever dia...    negative
# 31  The feature 'Concentration of Very Small VLDL ...    negative
# 13  The feature 'SHBG' (Sex Hormone Binding Globul...    positive
# 50  This feature is interesting because it reveals...     neutral
# 39  1. **Novelty:** The association between urban ...    positive
# 19  1. **Novelty:** The association between SLE ge...    positive
# 42  1. **Novelty:** The association between trigly...    positive
# 15  The feature 'PSO psoriasis genetic risk' is ev...    negative
# 5   The feature 'Mental health conditions ever dia...    negative
# 22  1. **Novelty:** The feature 'HBA1C DF glycated...    positive
# 21  1. **Novelty:** The feature 'Acetoacetate' in ...    positive
# 45  Interestingness: The feature 'Z90.4 - Acquired...    negative
# 26  1. **Novelty:** The association between wheezi...    positive
# 17  1. **Novelty:** The association between Vitami...    negative
# 2   The feature 'Hypotension NOS' in relation to o...    positive
# 9   The feature 'Mouth teeth dental problems Dentu...    positive
#
#                Target Comments
# 14  oesophagus cancer
# 32  oesophagus cancer
# 51  oesophagus cancer
# 3   oesophagus cancer
# 41  oesophagus cancer
# 24  oesophagus cancer
# 48  oesophagus cancer
# 44  oesophagus cancer
# 35  oesophagus cancer
# 37  oesophagus cancer
# 1   oesophagus cancer
# 23  oesophagus cancer
# 34  oesophagus cancer
# 30  oesophagus cancer
# 27  oesophagus cancer
# 8   oesophagus cancer
# 43  oesophagus cancer
# 49  oesophagus cancer
# 46  oesophagus cancer
# 25  oesophagus cancer
# 18  oesophagus cancer
# 36  oesophagus cancer
# 29  oesophagus cancer
# 28  oesophagus cancer
# 10  oesophagus cancer
# 38  oesophagus cancer
# 4   oesophagus cancer
# 40  oesophagus cancer
# 0   oesophagus cancer
# 7   oesophagus cancer
# 12  oesophagus cancer
# 11  oesophagus cancer
# 6   oesophagus cancer
# 16  oesophagus cancer
# 20  oesophagus cancer
# 47  oesophagus cancer
# 33  oesophagus cancer
# 31  oesophagus cancer
# 13  oesophagus cancer
# 50  oesophagus cancer
# 39  oesophagus cancer
# 19  oesophagus cancer
# 42  oesophagus cancer
# 15  oesophagus cancer
# 5   oesophagus cancer
# 22  oesophagus cancer
# 21  oesophagus cancer
# 45  oesophagus cancer
# 26  oesophagus cancer
# 17  oesophagus cancer
# 2   oesophagus cancer
# 9   oesophagus cancer
# eye_occ_
# 49 # Positive candidates (pre limit)
# Excel sheet with annotation logic saved to ./Outputs/for_annotators/eye_occ_candidates.xlsx.
#                                          Feature_Name  \
# 22     Alcohol intake frequency._Once or twice a week
# 1                 (ISS) ischaemic stroke genetic risk
# 36                  Oily fish intake_5-6 times a week
# 52                                            Acetone
# 53                                         Duodenitis
# 37  Non-cancer illness code, self-reported | Array...
# 47             Number of treatments/medications taken
# 45                     Concentration of IDL Particles
# 55  Ever addicted to a behaviour or miscellanous_None
# 50               Hemorrhage of gastrointestinal tract
# 56  Ever addicted to illicit or recreational drugs...
# 29                                               SHBG
# 25                 (CED) coeliac disease genetic risk
# 33  Non-cancer illness code, self-reported | Array...
# 49                                  3-Hydroxybutyrate
# 34  Mental health conditions ever diagnosed by a p...
# 16  Z92.1 - Personal history of long-term (current...
# 15                       Illnesses of siblings_3_None
# 32  Doctor diagnosed COPD (chronic obstructive pul...
# 41                 Average Diameter for LDL Particles
# 3   Home area population density - urban or rural_...
# 19              Concentration of Medium LDL Particles
# 10                  (CD) crohn's disease genetic risk
# 14                           Gastritis and duodenitis
# 6   Other serious medical condition/disability dia...
# 17                      LDL direct Blood biochemistry
# 46  Non-cancer illness code, self-reported | Array...
# 24  Home area population density - urban or rural_...
# 9             (IOP) intraocular pressure genetic risk
# 27                      missing_Microalbumin in urine
# 38  Wheeze or whistling in the chest in last year_...
# 43  Symptoms concerning nutrition, metabolism, and...
# 12              (AD) alzheimer's disease genetic risk
# 31  Non-cancer illness code, self-reported | Array...
# 4                    Health satisfaction_Very unhappy
# 57  Ever addicted to a behaviour or miscellanous_i...
# 51                 Cellulitis and abscess of arm/hand
# 44                           Cholesterol in Small LDL
# 11                       (HEIGHT) height genetic risk
# 0   Home area population density - urban or rural_...
# 26                             Oily fish intake_Never
# 20                      Gestational diabetes only_Yes
# 30                                          Vitamin D
# 54  Ever addicted to illicit or recreational drugs...
# 39  Medication for cholesterol, blood pressure, di...
# 48  Acceptability of each blow result (text) | Arr...
# 2                 (AAM) age at menopause genetic risk
# 7                  (T1D) type 1 diabetes genetic risk
# 23  Time spent outdoors in winter_Less than an hou...
# 21                                 Cholesterol in IDL
# 18  Long-standing illness, disability or infirmity_No
# 8          (CAD) coronary artery disease genetic risk
# 13   (VTE) venous thromboembolic disease genetic risk
# 42                     Cholesterol Blood biochemistry
# 28  Non-cancer illness code, self-reported | Array...
# 40  Weight change during worst episode of depressi...
# 35  Non-cancer illness code, self-reported | Array...
# 5   Vascular/heart problems diagnosed by doctor_No...
#
#                                           explanation correlation  \
# 22  1. **Novelty:** The relationship between moder...    negative
# 1   The feature '(ISS) ischaemic stroke genetic ri...    positive
# 36  The feature 'Oily fish intake 5-6 times a week...    positive
# 52  The feature 'Acetone' is interesting in the co...     neutral
# 53  The feature 'Duodenitis' is interesting becaus...    negative
# 37  1. **Novelty:** The relationship between chron...    negative
# 47  The feature 'Number of treatments/medications ...    positive
# 45  The feature 'Concentration of IDL Particles' p...    negative
# 55  The feature 'Ever addicted to a behaviour or m...    negative
# 50  The feature 'Hemorrhage of gastrointestinal tr...    negative
# 56  The feature 'Ever addicted to illicit or recre...    negative
# 29  1. **Novelty:** SHBG (Sex Hormone Binding Glob...    negative
# 25  The feature 'CED coeliac disease genetic risk'...    positive
# 33  1. **Novelty:** The association between myxoed...    negative
# 49  The feature '3-Hydroxybutyrate' is interesting...    positive
# 34  The feature 'Mental health conditions ever dia...    negative
# 16  The feature 'Z92.1 - Personal history of long-...    positive
# 15  The feature 'Illnesses of siblings' in relatio...    negative
# 32  The feature 'Doctor diagnosed COPD' having a n...    negative
# 41  The feature 'Average Diameter for LDL Particle...    negative
# 3   The feature 'Home area population density - ur...    negative
# 19  The feature 'Concentration of Medium LDL Parti...    negative
# 10  The feature 'CD crohn's disease genetic risk' ...    negative
# 14  1. **Novelty:** The association between gastri...    positive
# 6   The feature 'Other serious medical condition/d...    negative
# 17  The feature 'LDL direct Blood biochemistry' pr...    negative
# 46  The feature 'emphysema chronic' as negatively ...    negative
# 24  The feature 'Home area population density - ur...    positive
# 9   The feature 'IOP intraocular pressure genetic ...    positive
# 27  1. **Novelty:** The association between microa...    negative
# 38  The feature 'Wheeze or whistling in the chest ...    positive
# 43  The feature 'Symptoms concerning nutrition, me...    positive
# 12  The feature 'AD Alzheimer's disease genetic ri...    negative
# 31  1. **Novelty:** The association between depres...    positive
# 4   The feature 'Health satisfaction Very unhappy'...    positive
# 57  The feature 'Ever addicted to a behaviour or m...    negative
# 51  Cellulitis and abscess of arm/hand is interest...    positive
# 44  The feature 'Cholesterol in Small LDL' in rela...    negative
# 11  The feature 'HEIGHT height genetic risk' is ev...    negative
# 0   The feature 'Home area population density - ur...    negative
# 26  The feature 'Oily fish intake Never' is evalua...    negative
# 20  The feature 'Gestational diabetes only' is int...    positive
# 30  The feature 'Vitamin D' in relation to retinal...    negative
# 54  **Explanation:** This feature is interesting b...    negative
# 39  The feature 'Medication for cholesterol, blood...    negative
# 48  The feature 'Acceptability of each blow result...    positive
# 2   The feature '(AAM) age at menopause genetic ri...    positive
# 7   The feature 'T1D type 1 diabetes genetic risk'...    positive
# 23  The feature 'Time spent outdoors in winter Les...    negative
# 21  The feature 'Cholesterol in IDL' is interestin...    negative
# 18  1. **Novelty**: The feature 'Long-standing ill...    negative
# 8   The feature 'CAD coronary artery disease genet...    positive
# 13  The feature 'VTE venous thromboembolic disease...    negative
# 42  The feature 'Cholesterol Blood biochemistry' s...    negative
# 28  The feature 'hypothyroidism' is evaluated for ...    negative
# 40  The feature 'Weight change during worst episod...    positive
# 35  The feature 'osteoarthritis' in relation to re...    positive
# 5   The feature 'Vascular/heart problems diagnosed...    negative
#
#                                                Target Comments
# 22  (Retinal Vein Occlusion) OR (Central retinal a...
# 1   (Retinal Vein Occlusion) OR (Central retinal a...
# 36  (Retinal Vein Occlusion) OR (Central retinal a...
# 52  (Retinal Vein Occlusion) OR (retinal artery oc...
# 53  (Retinal Vein Occlusion) OR (retinal artery oc...
# 37  (Retinal Vein Occlusion) OR (Central retinal a...
# 47  (Retinal Vein Occlusion) OR (Central retinal a...
# 45  (Retinal Vein Occlusion) OR (Central retinal a...
# 55  (Retinal Vein Occlusion) OR (retinal artery oc...
# 50  (Retinal Vein Occlusion) OR (retinal artery oc...
# 56  (Retinal Vein Occlusion) OR (retinal artery oc...
# 29  (Retinal Vein Occlusion) OR (Central retinal a...
# 25  (Retinal Vein Occlusion) OR (Central retinal a...
# 33  (Retinal Vein Occlusion) OR (Central retinal a...
# 49  (Retinal Vein Occlusion) OR (retinal artery oc...
# 34  (Retinal Vein Occlusion) OR (Central retinal a...
# 16  (Retinal Vein Occlusion) OR (Central retinal a...
# 15  (Retinal Vein Occlusion) OR (Central retinal a...
# 32  (Retinal Vein Occlusion) OR (Central retinal a...
# 41  (Retinal Vein Occlusion) OR (Central retinal a...
# 3   (Retinal Vein Occlusion) OR (Central retinal a...
# 19  (Retinal Vein Occlusion) OR (Central retinal a...
# 10  (Retinal Vein Occlusion) OR (Central retinal a...
# 14  (Retinal Vein Occlusion) OR (Central retinal a...
# 6   (Retinal Vein Occlusion) OR (Central retinal a...
# 17  (Retinal Vein Occlusion) OR (Central retinal a...
# 46  (Retinal Vein Occlusion) OR (Central retinal a...
# 24  (Retinal Vein Occlusion) OR (Central retinal a...
# 9   (Retinal Vein Occlusion) OR (Central retinal a...
# 27  (Retinal Vein Occlusion) OR (Central retinal a...
# 38  (Retinal Vein Occlusion) OR (Central retinal a...
# 43  (Retinal Vein Occlusion) OR (Central retinal a...
# 12  (Retinal Vein Occlusion) OR (Central retinal a...
# 31  (Retinal Vein Occlusion) OR (Central retinal a...
# 4   (Retinal Vein Occlusion) OR (Central retinal a...
# 57  (Retinal Vein Occlusion) OR (retinal artery oc...
# 51  (Retinal Vein Occlusion) OR (retinal artery oc...
# 44  (Retinal Vein Occlusion) OR (Central retinal a...
# 11  (Retinal Vein Occlusion) OR (Central retinal a...
# 0   (Retinal Vein Occlusion) OR (Central retinal a...
# 26  (Retinal Vein Occlusion) OR (Central retinal a...
# 20  (Retinal Vein Occlusion) OR (Central retinal a...
# 30  (Retinal Vein Occlusion) OR (Central retinal a...
# 54  (Retinal Vein Occlusion) OR (retinal artery oc...
# 39  (Retinal Vein Occlusion) OR (Central retinal a...
# 48  (Retinal Vein Occlusion) OR (Central retinal a...
# 2   (Retinal Vein Occlusion) OR (Central retinal a...
# 7   (Retinal Vein Occlusion) OR (Central retinal a...
# 23  (Retinal Vein Occlusion) OR (Central retinal a...
# 21  (Retinal Vein Occlusion) OR (Central retinal a...
# 18  (Retinal Vein Occlusion) OR (Central retinal a...
# 8   (Retinal Vein Occlusion) OR (Central retinal a...
# 13  (Retinal Vein Occlusion) OR (Central retinal a...
# 42  (Retinal Vein Occlusion) OR (Central retinal a...
# 28  (Retinal Vein Occlusion) OR (Central retinal a...
# 40  (Retinal Vein Occlusion) OR (Central retinal a...
# 35  (Retinal Vein Occlusion) OR (Central retinal a...
# 5   (Retinal Vein Occlusion) OR (Central retinal a...
# depression_
# 20 # Positive candidates (pre limit)
# Excel sheet with annotation logic saved to ./Outputs/for_annotators/depression_candidates.xlsx.
#                                          Feature_Name  \
# 14                                   Skin colour_Fair
# 20    Nonspecific abnormal findings in stool contents
# 1   missing_Peripheral enthesopathies and allied s...
# 6                      missing_Hallux valgus (Bunion)
# 8           Other diseases of respiratory system, NEC
# 15                      missing_Polyp of corpus uteri
# 13                             missing_Diverticulosis
# 22                       Z51.0 - Radiotherapy session
# 23       Age other serious eye condition diagnosed_66
# 19                        (MEL) melanoma genetic risk
# 2                    missing_Gastritis and duodenitis
# 18                                              Urate
# 16  missing_(EOC) epithelial ovarian cancer geneti...
# 11                              Microalbumin in urine
# 3                         Pulse wave reflection index
# 5             Cholelithiasis with other cholecystitis
# 7           missing_Other open wound of head and face
# 17                           Alanine aminotransferase
# 0                                       Total protein
# 10  Home area population density - urban or rural_...
# 9                                     Basophill count
# 21                           Acquired toe deformities
# 4     missing_Septal Deviations/Turbinate Hypertrophy
# 12                  (CD) crohn's disease genetic risk
#
#                                           explanation correlation  \
# 14  The feature 'Skin colour Fair' as a predictor ...    positive
# 20  The feature 'Nonspecific abnormal findings in ...    positive
# 1   1. **Novelty:** The relationship between perip...     neutral
# 6   1. **Novelty:** The association between hallux...     neutral
# 8   1. **Novelty:** The feature 'Other diseases of...    positive
# 15  The feature 'Polyp of corpus uteri' in relatio...    negative
# 13  1. **Novelty:** The association between divert...    positive
# 22  The feature 'Z51.0 - Radiotherapy session' is ...    negative
# 23  The feature 'Age other serious eye condition d...     neutral
# 19  The feature '(MEL) melanoma genetic risk' in r...     neutral
# 2   1. **Novelty:** The association between gastri...     neutral
# 18  The feature 'Urate' in relation to depression ...    positive
# 16  The feature 'EOC epithelial ovarian cancer gen...    negative
# 11  The feature 'Microalbumin in urine' is conside...     neutral
# 3   The feature 'Pulse wave reflection index' in r...    positive
# 5   The feature 'Cholelithiasis with other cholecy...    positive
# 7   1. **Novelty:** The feature 'Other open wound ...    positive
# 17  The feature 'Alanine aminotransferase (ALT)' i...     neutral
# 0   1. **Novelty:** The association between total ...     neutral
# 10  The feature 'Home area population density - ur...    negative
# 9   1. **Novelty:** The relationship between basop...    positive
# 21  Acquired toe deformities are interesting becau...    positive
# 4   The feature 'Septal Deviations Turbinate Hyper...    positive
# 12  The feature 'CD Crohn's disease genetic risk' ...    negative
#
#                                    Target Comments
# 14  (Depression) OR (Depressive disorder)
# 20  (Depression) OR (Depressive disorder)
# 1   (Depression) OR (Depressive disorder)
# 6   (Depression) OR (Depressive disorder)
# 8   (Depression) OR (Depressive disorder)
# 15  (Depression) OR (Depressive disorder)
# 13  (Depression) OR (Depressive disorder)
# 22  (Depression) OR (Depressive disorder)
# 23  (Depression) OR (Depressive disorder)
# 19  (Depression) OR (Depressive disorder)
# 2   (Depression) OR (Depressive disorder)
# 18  (Depression) OR (Depressive disorder)
# 16  (Depression) OR (Depressive disorder)
# 11  (Depression) OR (Depressive disorder)
# 3   (Depression) OR (Depressive disorder)
# 5   (Depression) OR (Depressive disorder)
# 7   (Depression) OR (Depressive disorder)
# 17  (Depression) OR (Depressive disorder)
# 0   (Depression) OR (Depressive disorder)
# 10  (Depression) OR (Depressive disorder)
# 9   (Depression) OR (Depressive disorder)
# 21  (Depression) OR (Depressive disorder)
# 4   (Depression) OR (Depressive disorder)
# 12  (Depression) OR (Depressive disorder)
# heart_
# 32 # Positive candidates (pre limit)
# Excel sheet with annotation logic saved to ./Outputs/for_annotators/heart_candidates.xlsx.
#                                          Feature_Name  \
# 27                                    Basophill count
# 15                 (BD) bipolar disorder genetic risk
# 17                   missing_Fluid intelligence score
# 21                                 Fed-up feelings_No
# 35                           Gastritis and duodenitis
# 5   Home area population density - urban or rural_...
# 22              Most recent bowel cancer screening_10
# 19                                    Standing height
# 34                                         Duodenitis
# 28                     Hot drink temperature_Very hot
# 11  Long-term/recurrent antibiotics as child or te...
# 30                       Alcohol drinker status_Never
# 20                 (CED) coeliac disease genetic risk
# 1         missing_Other non-epithelial cancer of skin
# 29  Started insulin within one year diagnosis of d...
# 18  Mental health conditions ever diagnosed by a p...
# 31                 (BMI) body mass index genetic risk
# 2                            Health satisfaction_None
# 4                 (AAM) age at menopause genetic risk
# 12  Long-standing illness, disability or infirmity_No
# 3   Home area population density - urban or rural_...
# 23                    Time spend outdoors in summer_8
# 33       Z90.7 - Acquired absence of genital organ(s)
# 8   Mental health conditions ever diagnosed by a p...
# 26                       missing_Tobacco use disorder
# 37  Behavioural and miscellaneous addictions_A beh...
# 0                           (AST) asthma genetic risk
# 25  Non-cancer illness code, self-reported | Array...
# 16  Home area population density - urban or rural_...
# 32  Z90.4 - Acquired absence of other parts of dig...
# 14                                 Potassium in urine
# 24                    Time spent outdoors in winter_4
# 9                              missing_Diverticulosis
# 36  Behavioural and miscellaneous addictions_Somet...
# 10  Home area population density - urban or rural_...
# 6                           Leg fat-free mass (right)
# 7                      (OP) osteoporosis genetic risk
# 13  Wheeze or whistling in the chest in last year_Yes
#
#                                           explanation correlation  \
# 27  1. **Novelty:** The relationship between basop...    negative
# 15  The feature 'BD bipolar disorder genetic risk'...    positive
# 17  1. **Novelty:** The association between fluid ...    positive
# 21  1. **Novelty:** The feature 'Fed up feelings' ...    negative
# 35  ## Interestingness Explanation:\nThe feature '...    positive
# 5   The feature 'Home area population density - ur...    negative
# 22  The feature 'Most recent bowel cancer screenin...    negative
# 19  1. **Novelty:** The association between standi...    negative
# 34  Duodenitis is interesting because it shows a n...    negative
# 28  The feature 'Hot drink temperature Very hot' i...    negative
# 11  The feature 'Long term recurrent antibiotics a...    positive
# 30  The feature 'Alcohol drinker status Never' bei...    positive
# 20  1. **Novelty:** The association between coelia...    positive
# 1   1. **Novelty:** The association between 'Other...    positive
# 29  1. **Novelty:** The feature 'Started insulin w...    positive
# 18  The feature 'Mental health conditions ever dia...    negative
# 31  The feature '(BMI) body mass index genetic ris...    positive
# 2   The feature 'Health satisfaction' in relation ...    positive
# 4   The feature '(AAM) age at menopause genetic ri...    positive
# 12  The feature 'Long-standing illness, disability...    negative
# 3   The feature 'Home area population density - ur...    negative
# 23  1. **Novelty:** The association between 'Time ...    positive
# 33  The feature 'Z90.7 - Acquired absence of genit...    negative
# 8   The feature 'Mental health conditions ever dia...    negative
# 26  The feature 'Tobacco use disorder' is traditio...    negative
# 37  This feature is interesting because it provide...    negative
# 0   1. **Novelty:** The association between asthma...    positive
# 25  The feature 'Non-cancer illness code, self-rep...    negative
# 16  The feature 'Home area population density - ur...    positive
# 32  Interestingness: The feature 'Z90.4 - Acquired...    negative
# 14  The feature 'Potassium in urine' and its negat...    negative
# 24  The feature 'Time spent outdoors in winter' is...    positive
# 9   The feature 'Diverticulosis' in relation to pr...    negative
# 36  The feature 'Behavioural and miscellaneous add...    positive
# 10  1. **Novelty:** The association between urban ...    positive
# 6   The feature 'Leg fat-free mass' is interesting...    negative
# 7   The feature 'OP osteoporosis genetic risk' in ...    positive
# 13  1. **Novelty:** The association between wheezi...    positive
#
#           Target Comments
# 27  Heart attack
# 15  Heart attack
# 17  Heart attack
# 21  Heart attack
# 35  Heart attack
# 5   Heart attack
# 22  Heart attack
# 19  Heart attack
# 34  Heart attack
# 28  Heart attack
# 11  Heart attack
# 30  Heart attack
# 20  Heart attack
# 1   Heart attack
# 29  Heart attack
# 18  Heart attack
# 31  Heart attack
# 2   Heart attack
# 4   Heart attack
# 12  Heart attack
# 3   Heart attack
# 23  Heart attack
# 33  Heart attack
# 8   Heart attack
# 26  Heart attack
# 37  Heart attack
# 0   Heart attack
# 25  Heart attack
# 16  Heart attack
# 32  Heart attack
# 14  Heart attack
# 24  Heart attack
# 9   Heart attack
# 36  Heart attack
# 10  Heart attack
# 6   Heart attack
# 7   Heart attack
# 13  Heart attack

# %%
# df.iloc[0]["explanation"]

# %%
display(df_pos.head(2).select_dtypes("O"))
# Out:
#                                   Feature_Name  \
# 0                    (AST) asthma genetic risk
# 1  missing_Other non-epithelial cancer of skin
#
#                                            novel_cot  \
# 0  The relationship between asthma and heart dise...
# 1  The association between 'Other non-epithelial ...
#
#                                        plausible_cot  \
# 0  To determine if there is a plausible explanati...
# 1  To determine if there is a plausible explanati...
#
#                                          explanation  \
# 0  1. **Novelty:** The association between asthma...
# 1  1. **Novelty:** The association between 'Other...
#
#                                F.Split-Feature Split  \
# 0         -0.48 <= (AST) asthma genetic risk < -0.48
# 1  missing_Other non-epithelial cancer of skin >=...
#
#                                           boring_cot        Target
# 0  The association between (AST) asthma genetic r...  Heart attack
# 1  The feature 'Other non-epithelial cancer of sk...  Heart attack

# %%
set(df_pos.columns).intersection(set(df_neg.columns))
# Out:
# {'Feature_Name',
#  'MutualInfoTarget',
#  'Real',
#  'Target',
#  'corr',
#  'explanation',
#  'feature_importance',
#  'p_val'}
